# %% [markdown]
# # Preprocessing

# %%
import os
import datetime as dt

import copy
import IPython
import numpy as np
import pandas as pd
import seaborn as sns
import IPython.display
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt

from scipy.signal import savgol_filter

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
# Out:
# 2022-04-25 22:59:15.645854: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-25 22:59:15.645896: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Macros
BY_ZONE = False # True if you want grouping by zones (Nord, Centro, Sud, Sardegna)
BY_REGION = True # True if you want to keep single regions

# %%
# File name
#file_path = "../Data/dpc-covid19-ita-regioni.csv"
file_path = '../Data/dpc-covid19-ita-regioni.csv'
features_list = ["totale_ospedalizzati", "nuovi_positivi", "dimessi_guariti", "deceduti"]

# Load data
df_all = pd.read_csv(
    file_path,
    usecols = ["data", "denominazione_regione", "nuovi_positivi", "totale_ospedalizzati", "dimessi_guariti", "deceduti"],
    parse_dates = True,
)

# Convert data coulumn
df_all["data"] = pd.to_datetime(df_all["data"]).dt.date

# Keep only latest data wrt cut_date
cut_date_3 = dt.date(2022, 2, 10)    #(2022, 1, 10)
cut_date_2 = dt.date(2021, 10, 1)
cut_date_1 = dt.date(2021, 3, 1)  

df_all = df_all.loc[ ((df_all["data"] >= cut_date_1) & (df_all["data"] <= cut_date_2)) | (df_all["data"] >= cut_date_3)]

# %%
# Create 4 groups of regions
# NON SONO SICURO PERO': LUI CHIEDE ESPRESSAMENTE REGIONI!
if BY_ZONE:
    
    Nord = ["Emilia-Romagna", 
            "Friuli Venezia Giulia", 
            "Lombardia", 
            "P.A. Bolzano", 
            "P.A. Trento", 
            "Piemonte", 
            "Toscana", 
            "Valle d'Aosta",
            "Veneto"
           ]
    Centro = ["Abruzzo",
              "Lazio",
              "Marche",
              "Molise",
              "Umbria",
             ]

    Sud = ["Basilicata",
           "Calabria",
           "Campania",
           "Puglia",
           "Sicilia"
          ]

    Sardegna = ["Sardegna"]

    df_Nord = df_all.loc[df_all['denominazione_regione'].isin(Nord)]
    df_Nord.pop("denominazione_regione")
    df_Nord = df_Nord.groupby(["data"]).sum()
    df_Nord.reset_index(drop=False, inplace=True)

    df_Centro = df_all.loc[df_all['denominazione_regione'].isin(Centro)]
    df_Centro.pop("denominazione_regione")
    df_Centro = df_Centro.groupby(["data"]).sum()
    df_Centro.reset_index(drop=False, inplace=True)

    
    df_Sud = df_all.loc[df_all['denominazione_regione'].isin(Sud)]
    df_Sud.pop("denominazione_regione")
    df_Sud = df_Sud.groupby(["data"]).sum()
    df_Sud.reset_index(drop=False, inplace=True)

    
    df_Sardegna = df_all.loc[df_all['denominazione_regione'].isin(Sardegna)]
    df_Sardegna.pop("denominazione_regione")
    df_Sardegna = df_Sardegna.groupby(["data"]).sum()
    df_Sardegna.reset_index(drop=False, inplace=True)

# %%
df_tot = pd.DataFrame()

if BY_REGION:
    
    df_by_region = dict() # dictionary containing data for each regione

    regions = list(df_all.loc[:,"denominazione_regione"].unique())
    
    for reg in regions:
        
        df_by_region[reg] = df_all.loc[df_all["denominazione_regione"] == reg]
        columns_={"totale_ospedalizzati": "totale_ospedalizzati_" + reg, 
                 "nuovi_positivi": "nuovi_positivi_" + reg, 
                 "dimessi_guariti" : "dimessi_guariti_" + reg, 
                 "deceduti": "deceduti_" + reg}
        df_by_region[reg].pop("denominazione_regione")
        df_by_region[reg] = df_by_region[reg].rename(columns = columns_)
        df_by_region[reg].set_index("data", inplace = True)
       
        if df_tot.shape[0] == 0:
            df_tot = df_by_region[reg].iloc[:,1:]
        else:
            df_tot = pd.concat([df_tot, df_by_region[reg].iloc[:,1:]], axis=1)

# %% [markdown]
#  # RNN

# %% [markdown]
# ## Tensorflow modified classes

# %%
# FUNCTIONALITIES

# Window generator
class WindowGenerator():
  def __init__(self, input_width, label_width, shift,
               train_df, val_df=None, test_df=None,
               label_columns=None, batch_size = 32):
    # Store the raw data.
    self.train_df = train_df
    self.val_df = val_df
    self.test_df = test_df
    self.batch_size = batch_size
    
    # Work out the label column indices.
    self.label_columns = label_columns
    if label_columns is not None:
      self.label_columns_indices = {name: i for i, name in
                                    enumerate(label_columns)}
    self.column_indices = {name: i for i, name in
                           enumerate(train_df.columns)}

    # Work out the window parameters.
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift

    self.total_window_size = input_width + shift

    self.input_slice = slice(0, input_width)
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]

    self.label_start = self.total_window_size - self.label_width
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

  def __repr__(self):
    return '\n'.join([
        f'Total window size: {self.total_window_size}',
        f'Input indices: {self.input_indices}',
        f'Label indices: {self.label_indices}',
        f'Label column name(s): {self.label_columns}'])

# Split window
def split_window(self, features):
  inputs = features[:, self.input_slice, :]
  labels = features[:, self.labels_slice, :]
  if self.label_columns is not None:
    labels = tf.stack(
        [labels[:, :, self.column_indices[name]] for name in self.label_columns],
        axis=-1)

  # Slicing doesn't preserve static shape information, so set the shapes
  # manually. This way the `tf.data.Datasets` are easier to inspect.
  inputs.set_shape([None, self.input_width, None])
  labels.set_shape([None, self.label_width, None])

  return inputs, labels

WindowGenerator.split_window = split_window

# plot function
def plot(self, model=None, plot_col='nuovi_positivi_Lombardia', max_subplots=32):
  inputs, labels = self.example
  plt.figure(figsize=(12, 8))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.figure()
    #plt.subplot(max_n, 1, n+1)
    plt.ylabel(f'{plot_col} [normed]')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [h]')

WindowGenerator.plot = plot

# make tf.dataset
def make_dataset(self, data, batch_size):
  data = np.array(data, dtype=np.float32)
  ds = tf.keras.utils.timeseries_dataset_from_array(
      data=data,
      targets=None,
      sequence_length=self.total_window_size,
      sequence_stride=1,
      shuffle=False,
      batch_size=batch_size,)

  ds = ds.map(self.split_window)

  return ds

WindowGenerator.make_dataset = make_dataset

# Properties
@property
def train(self):
  return self.make_dataset(self.train_df, self.batch_size)

@property
def val(self):
  return self.make_dataset(self.val_df, self.batch_size)

@property
def test(self):
  return self.make_dataset(self.test_df, self.batch_size)

@property
def example(self):
  """Get and cache an example batch of `inputs, labels` for plotting."""
  result = getattr(self, '_example', None)
  if result is None:
    # No example batch was found, so get one from the `.train` dataset
    result = next(iter(self.train))
    # And cache it for next time
    self._example = result
  return result

WindowGenerator.train = train
WindowGenerator.val = val
WindowGenerator.test = test
WindowGenerator.example = example

# %% [markdown]
# ## Training-Validation-Test sets creation

# %%
df_by_region['Lombardia'].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='data'>, <AxesSubplot:xlabel='data'>,
#        <AxesSubplot:xlabel='data'>, <AxesSubplot:xlabel='data'>],
#       dtype=object)

# %%
regions_train = ["Lombardia"]   # name of regions to train simultaneously

NORMALIZATION = False
PCT_CHANGE = True
DIFF = False
APPLY_SMOOTHING = False
VALIDATION = True

all_df = dict()
all_df_1 = dict()
all_df_2 = dict()
train_df = dict() # dictionary of training dataFrames 
if VALIDATION:
    val_df = dict() # validation temporarily ignored
test_df = dict() # dictionary of test dataframes

OUT_STEPS = 7 # length of prediction horizon (OUTPUT OF NN)
IN_STEPS = 28 # length of input horizon (INPUT OF NN)
SHIFT = OUT_STEPS # Can be different from OUT_STEPS (to be used with care)

time_steps_for_test = OUT_STEPS # Numbers of days to keep out for the validation (in principle it should be of length: OUT_STEP+IN_STEPS), but we can use just OUT_STEPS
if VALIDATION:
    time_steps_for_validation = IN_STEPS+OUT_STEPS

# FOR THE NORMALIZATION I USE THE MEANS OF TRAIN FOR BOTH TRAINING AND TESTING
for reg in regions_train:

    mean = 0
    std = 1

    if PCT_CHANGE:

      all_df_1[reg] = copy.deepcopy(df_by_region[reg].loc[ ((df_by_region[reg].index >= cut_date_1) & (df_by_region[reg].index <= cut_date_2)) ])
      all_df_2[reg] = copy.deepcopy(df_by_region[reg].loc[ (df_by_region[reg].index >= cut_date_3)])
      all_df_1[reg] = all_df_1[reg].pct_change().dropna()
      all_df_2[reg] = all_df_2[reg].pct_change().dropna()
      all_df[reg] = pd.concat([all_df_1[reg], all_df_2[reg]], axis = 0, ignore_index = True)
    
    if DIFF:

      all_df_1[reg] = copy.deepcopy(df_by_region[reg].loc[ ((df_by_region[reg].index >= cut_date_1) & (df_by_region[reg].index <= cut_date_2)) ])
      all_df_2[reg] = copy.deepcopy(df_by_region[reg].loc[ (df_by_region[reg].index >= cut_date_3)])
      all_df_1[reg] = all_df_1[reg].diff().dropna()
      all_df_2[reg] = all_df_2[reg].diff().dropna()
      all_df[reg] = pd.concat([all_df_1[reg], all_df_2[reg]], axis = 0, ignore_index = True)
    
    if NORMALIZATION:
      mean = all_df[reg].iloc[:-time_steps_for_test,:].mean()
      std = all_df[reg].iloc[:-time_steps_for_test,:].std()
      
    all_df[reg] = ( all_df[reg] - mean ) / std

    if APPLY_SMOOTHING:
        
        window_length = 3 # MUST BE ODD; if you put 7 you obtain just the trend
        polyorder = 1 # Try also 2, 3, ...
        
        all_df[reg].loc[:, "{}_{}".format("nuovi_positivi", reg)] = savgol_filter(
                all_df[reg].loc[:, "{}_{}".format("nuovi_positivi", reg)],
                window_length,
                polyorder
            )
    
    if VALIDATION:
        train_df[reg] = all_df[reg].iloc[:-(time_steps_for_test + time_steps_for_validation),:]
        val_df[reg] = all_df[reg].iloc[ -(time_steps_for_test + time_steps_for_validation) : -time_steps_for_test, :]
        test_df[reg] = all_df[reg].iloc[-time_steps_for_test:,:]
    else:
        train_df[reg] = all_df[reg].iloc[:-time_steps_for_test,:]
        test_df[reg] = all_df[reg].iloc[-time_steps_for_test:,:]

    
windows = dict() # dictionary of windows for each region
    
for reg in regions_train:
    if VALIDATION:
        windows[reg] =  WindowGenerator(input_width=IN_STEPS,
                                        label_width=OUT_STEPS,
                                        shift=SHIFT,
                                        train_df = train_df[reg],
                                        val_df = val_df[reg],
                                        batch_size = 16, ### DEAFULT = 32; can be modified by hand being careful
                                        #label_columns=['{}_{}'.format("nuovi_positivi", reg)] ### labels to train; we might split the training for the features since it may help the models...
                                        )
    else:
        windows[reg] =  WindowGenerator(input_width=IN_STEPS,
                                label_width=OUT_STEPS,
                                shift=SHIFT,
                                train_df = train_df[reg],
                                batch_size = 16, ### DEAFULT = 32; can be modified by hand being careful
                                #label_columns=['{}_{}'.format("nuovi_positivi", reg)] ### labels to train; we might split the training for the features since it may help the models...
                                )
        
def plot_feature(reg, feature, model = None, max_figures = 3):
    windows[reg].plot(model = model, plot_col = "{}_{}".format(feature, region), max_subplots=max_figures)
    plt.xticks(rotation=90)
    print("To view all the figures, increase max_figures")

# %%
val_df["Lombardia"].shape
# Out:
# (35, 4)

# %%
# check the training
train_df[regions_train[0]].plot(subplots=True)
plt.xticks(rotation=90)
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# check the smoothing

import copy

window_length = 3 # MUST BE ODD; if you put 7 you obtain just the trend
polyorder = 1 # Try also 2, 3, ...

savgol_smooth = copy.deepcopy(train_df)

savgol_smooth[reg].loc[:, "{}_{}".format("nuovi_positivi", reg)] = savgol_filter(
                savgol_smooth[reg].loc[:, "{}_{}".format("nuovi_positivi", reg)],
                window_length,
                polyorder
            )

window_smooth = train_df[reg]['nuovi_positivi_Lombardia'].rolling(window=2).mean()

train_df[regions_train[0]]['nuovi_positivi_Lombardia'].plot(label = 'Original')
savgol_smooth[reg]['nuovi_positivi_Lombardia'].plot(label = 'savgol')
window_smooth.dropna().plot(label="Rolling Window (2 days)")
plt.legend()
plt.xticks(rotation=90)
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Plot for viewing the batches
region = "Lombardia"
feature = "deceduti" #nuovi_positivi, dimessi_guariti, #totale_ospedalizzati
plot_feature(region, feature, max_figures=1)
# Out:
# To view all the figures, increase max_figures
# 2022-04-25 22:59:17.673247: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-04-25 22:59:17.673283: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-25 22:59:17.673296: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-H65JH0S): /proc/driver/nvidia/version does not exist
# 2022-04-25 22:59:17.673552: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Creation Training set for RNN

# Single region
if len(regions_train) == 1:

    X_train = windows[regions_train[0]].train
    X_val = None
    
    if VALIDATION:
        try:
            X_val =  windows[regions_train[0]].val
        except:
           print("Cannot create X_val with the given window size or val_df not present")

# Multiple regions
elif len(regions_train) > 1:
    
    print("More than one region...")
    
    for i in range(len(regions_train)-1):
        
        X_train = windows[regions_train[i]].train.concatenate(windows[regions_train[i+1]].train)
        X_val = None
        
        if VALIDATION:
            try:
                X_val = windows[regions_train[i]].val.concatenate(windows[regions_train[i+1]].val)
            except:
                print("Cannot create X_val with the given window size or val_df not present")

# %%
# IN THIS WAY YOU CAN EXTRACT THE TRAINING DATASET (Solution to the problem highlighted by Nove)
# list(X_train.as_numpy_iterator())

# %% [markdown]
# ## Multi-Steps

# %%
def compile_and_fit(model, X_train, MAX_EPOCHS = 200, X_val = None, patience=30):
  
  if X_val == None:
        monitor_loss = 'loss'
  else:
        monitor_loss = 'val_loss'
    
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor=monitor_loss, 
                                                    patience=patience,
                                                    mode='min')
  
  #easy_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = '/content/drive/Othercomputers/Laptop/homework3/Data/checkpoint_' + reg + '.h5',
  #                                                     save_weights_only = False, save_freq = 'epoch', monitor = monitor_loss, mode='min', 
  #                                                     save_best_only = True, verbose = 1)

  model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(),
                metrics=[tf.metrics.MeanAbsoluteError()])

  history = model.fit(X_train, epochs=MAX_EPOCHS,
                      validation_data=X_val,
                      callbacks=[early_stopping])    #callbacks= [early_stopping, easy_checkpoint])

  return history

# %%
# Current best model for PCT CHANGE

num_features = 4

multi_lstm_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, lstm_units].
    # Adding more `lstm_units` just overfits more quickly.
    tf.keras.layers.LSTM(16, return_sequences=False, kernel_regularizer = 'l2'),
    # Shape => [batch, out_steps*features].
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros()),
    # Shape => [batch, out_steps, features].
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

# %%
# model for PCT CHANGE

num_features = 4

multi_lstm_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, lstm_units].
    # Adding more `lstm_units` just overfits more quickly.
    tf.keras.layers.LSTM(16, return_sequences=False, kernel_regularizer = 'l2', activation='selu'),
    # Shape => [batch, out_steps*features].
    #tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros()),
    # Shape => [batch, out_steps, features].
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

# %%
if VALIDATION:
    history = compile_and_fit(multi_lstm_model, X_train, X_val = X_val, MAX_EPOCHS = 500, patience = 30)
else:
    history = compile_and_fit(multi_lstm_model, X_train, X_val = X_val, MAX_EPOCHS = 500, patience = 30)
# Out:
# Epoch 1/500
# 14/14 [==============================] - 1s 19ms/step - loss: 0.2097 - mean_absolute_error: 0.1211 - val_loss: 0.5277 - val_mean_absolute_error: 0.1912
# Epoch 2/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1959 - mean_absolute_error: 0.1288 - val_loss: 0.5020 - val_mean_absolute_error: 0.2185
# Epoch 3/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1901 - mean_absolute_error: 0.1352 - val_loss: 0.4912 - val_mean_absolute_error: 0.2015
# Epoch 4/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1816 - mean_absolute_error: 0.1289 - val_loss: 0.4823 - val_mean_absolute_error: 0.2021
# Epoch 5/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1755 - mean_absolute_error: 0.1316 - val_loss: 0.4754 - val_mean_absolute_error: 0.2067
# Epoch 6/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1705 - mean_absolute_error: 0.1323 - val_loss: 0.4701 - val_mean_absolute_error: 0.2060
# Epoch 7/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1658 - mean_absolute_error: 0.1316 - val_loss: 0.4613 - val_mean_absolute_error: 0.2045
# Epoch 8/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1617 - mean_absolute_error: 0.1314 - val_loss: 0.4550 - val_mean_absolute_error: 0.2046
# Epoch 9/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1582 - mean_absolute_error: 0.1315 - val_loss: 0.4500 - val_mean_absolute_error: 0.2046
# Epoch 10/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1551 - mean_absolute_error: 0.1313 - val_loss: 0.4448 - val_mean_absolute_error: 0.2041
# Epoch 11/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1521 - mean_absolute_error: 0.1308 - val_loss: 0.4369 - val_mean_absolute_error: 0.2029
# Epoch 12/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1495 - mean_absolute_error: 0.1304 - val_loss: 0.4272 - val_mean_absolute_error: 0.2013
# Epoch 13/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1469 - mean_absolute_error: 0.1296 - val_loss: 0.4160 - val_mean_absolute_error: 0.1986
# Epoch 14/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1444 - mean_absolute_error: 0.1286 - val_loss: 0.4084 - val_mean_absolute_error: 0.1964
# Epoch 15/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1423 - mean_absolute_error: 0.1278 - val_loss: 0.4116 - val_mean_absolute_error: 0.1968
# Epoch 16/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1396 - mean_absolute_error: 0.1263 - val_loss: 0.4077 - val_mean_absolute_error: 0.2008
# Epoch 17/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1363 - mean_absolute_error: 0.1258 - val_loss: 0.3745 - val_mean_absolute_error: 0.1950
# Epoch 18/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1322 - mean_absolute_error: 0.1255 - val_loss: 0.3711 - val_mean_absolute_error: 0.1904
# Epoch 19/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1260 - mean_absolute_error: 0.1255 - val_loss: 0.3139 - val_mean_absolute_error: 0.1793
# Epoch 20/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1212 - mean_absolute_error: 0.1275 - val_loss: 0.3081 - val_mean_absolute_error: 0.1844
# Epoch 21/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1174 - mean_absolute_error: 0.1242 - val_loss: 0.3082 - val_mean_absolute_error: 0.1852
# Epoch 22/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1155 - mean_absolute_error: 0.1240 - val_loss: 0.3072 - val_mean_absolute_error: 0.1845
# Epoch 23/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1138 - mean_absolute_error: 0.1241 - val_loss: 0.3116 - val_mean_absolute_error: 0.1856
# Epoch 24/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1124 - mean_absolute_error: 0.1238 - val_loss: 0.3121 - val_mean_absolute_error: 0.1839
# Epoch 25/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1110 - mean_absolute_error: 0.1224 - val_loss: 0.3103 - val_mean_absolute_error: 0.1848
# Epoch 26/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1097 - mean_absolute_error: 0.1221 - val_loss: 0.3111 - val_mean_absolute_error: 0.1900
# Epoch 27/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1079 - mean_absolute_error: 0.1224 - val_loss: 0.3052 - val_mean_absolute_error: 0.1885
# Epoch 28/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1062 - mean_absolute_error: 0.1220 - val_loss: 0.2919 - val_mean_absolute_error: 0.1829
# Epoch 29/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1045 - mean_absolute_error: 0.1210 - val_loss: 0.2829 - val_mean_absolute_error: 0.1814
# Epoch 30/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1025 - mean_absolute_error: 0.1194 - val_loss: 0.2851 - val_mean_absolute_error: 0.1770
# Epoch 31/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1001 - mean_absolute_error: 0.1159 - val_loss: 0.2888 - val_mean_absolute_error: 0.1689
# Epoch 32/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0949 - mean_absolute_error: 0.1106 - val_loss: 0.2666 - val_mean_absolute_error: 0.1774
# Epoch 33/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0924 - mean_absolute_error: 0.1105 - val_loss: 0.2493 - val_mean_absolute_error: 0.1708
# Epoch 34/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0901 - mean_absolute_error: 0.1106 - val_loss: 0.2416 - val_mean_absolute_error: 0.1688
# Epoch 35/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0879 - mean_absolute_error: 0.1099 - val_loss: 0.2375 - val_mean_absolute_error: 0.1692
# Epoch 36/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0867 - mean_absolute_error: 0.1086 - val_loss: 0.2357 - val_mean_absolute_error: 0.1697
# Epoch 37/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0864 - mean_absolute_error: 0.1073 - val_loss: 0.2344 - val_mean_absolute_error: 0.1694
# Epoch 38/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0866 - mean_absolute_error: 0.1067 - val_loss: 0.2301 - val_mean_absolute_error: 0.1679
# Epoch 39/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0863 - mean_absolute_error: 0.1063 - val_loss: 0.2253 - val_mean_absolute_error: 0.1648
# Epoch 40/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0853 - mean_absolute_error: 0.1058 - val_loss: 0.2189 - val_mean_absolute_error: 0.1615
# Epoch 41/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0842 - mean_absolute_error: 0.1057 - val_loss: 0.2136 - val_mean_absolute_error: 0.1589
# Epoch 42/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0834 - mean_absolute_error: 0.1056 - val_loss: 0.2100 - val_mean_absolute_error: 0.1571
# Epoch 43/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0829 - mean_absolute_error: 0.1051 - val_loss: 0.2072 - val_mean_absolute_error: 0.1556
# Epoch 44/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0827 - mean_absolute_error: 0.1046 - val_loss: 0.2039 - val_mean_absolute_error: 0.1530
# Epoch 45/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0823 - mean_absolute_error: 0.1043 - val_loss: 0.1994 - val_mean_absolute_error: 0.1502
# Epoch 46/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0818 - mean_absolute_error: 0.1041 - val_loss: 0.1944 - val_mean_absolute_error: 0.1474
# Epoch 47/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0812 - mean_absolute_error: 0.1038 - val_loss: 0.1895 - val_mean_absolute_error: 0.1435
# Epoch 48/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0806 - mean_absolute_error: 0.1034 - val_loss: 0.1845 - val_mean_absolute_error: 0.1394
# Epoch 49/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0804 - mean_absolute_error: 0.1030 - val_loss: 0.1792 - val_mean_absolute_error: 0.1337
# Epoch 50/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0800 - mean_absolute_error: 0.1026 - val_loss: 0.1732 - val_mean_absolute_error: 0.1280
# Epoch 51/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0794 - mean_absolute_error: 0.1022 - val_loss: 0.1686 - val_mean_absolute_error: 0.1206
# Epoch 52/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0785 - mean_absolute_error: 0.1018 - val_loss: 0.1605 - val_mean_absolute_error: 0.1163
# Epoch 53/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0782 - mean_absolute_error: 0.1013 - val_loss: 0.1549 - val_mean_absolute_error: 0.1130
# Epoch 54/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0777 - mean_absolute_error: 0.1005 - val_loss: 0.1474 - val_mean_absolute_error: 0.1083
# Epoch 55/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0773 - mean_absolute_error: 0.1000 - val_loss: 0.1414 - val_mean_absolute_error: 0.1046
# Epoch 56/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0768 - mean_absolute_error: 0.0994 - val_loss: 0.1355 - val_mean_absolute_error: 0.1017
# Epoch 57/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0763 - mean_absolute_error: 0.0988 - val_loss: 0.1300 - val_mean_absolute_error: 0.0995
# Epoch 58/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0759 - mean_absolute_error: 0.0984 - val_loss: 0.1257 - val_mean_absolute_error: 0.0980
# Epoch 59/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0756 - mean_absolute_error: 0.0978 - val_loss: 0.1230 - val_mean_absolute_error: 0.0987
# Epoch 60/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0752 - mean_absolute_error: 0.0971 - val_loss: 0.1205 - val_mean_absolute_error: 0.0984
# Epoch 61/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0749 - mean_absolute_error: 0.0967 - val_loss: 0.1174 - val_mean_absolute_error: 0.0981
# Epoch 62/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0746 - mean_absolute_error: 0.0962 - val_loss: 0.1162 - val_mean_absolute_error: 0.0994
# Epoch 63/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0742 - mean_absolute_error: 0.0957 - val_loss: 0.1149 - val_mean_absolute_error: 0.1002
# Epoch 64/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0740 - mean_absolute_error: 0.0954 - val_loss: 0.1136 - val_mean_absolute_error: 0.1008
# Epoch 65/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0737 - mean_absolute_error: 0.0950 - val_loss: 0.1125 - val_mean_absolute_error: 0.1015
# Epoch 66/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0735 - mean_absolute_error: 0.0946 - val_loss: 0.1120 - val_mean_absolute_error: 0.1030
# Epoch 67/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0732 - mean_absolute_error: 0.0942 - val_loss: 0.1111 - val_mean_absolute_error: 0.1039
# Epoch 68/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0728 - mean_absolute_error: 0.0939 - val_loss: 0.1104 - val_mean_absolute_error: 0.1046
# Epoch 69/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0726 - mean_absolute_error: 0.0936 - val_loss: 0.1099 - val_mean_absolute_error: 0.1048
# Epoch 70/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0725 - mean_absolute_error: 0.0933 - val_loss: 0.1094 - val_mean_absolute_error: 0.1055
# Epoch 71/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0722 - mean_absolute_error: 0.0928 - val_loss: 0.1091 - val_mean_absolute_error: 0.1061
# Epoch 72/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0720 - mean_absolute_error: 0.0925 - val_loss: 0.1085 - val_mean_absolute_error: 0.1069
# Epoch 73/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0718 - mean_absolute_error: 0.0922 - val_loss: 0.1079 - val_mean_absolute_error: 0.1078
# Epoch 74/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0715 - mean_absolute_error: 0.0920 - val_loss: 0.1072 - val_mean_absolute_error: 0.1085
# Epoch 75/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0713 - mean_absolute_error: 0.0918 - val_loss: 0.1067 - val_mean_absolute_error: 0.1096
# Epoch 76/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0712 - mean_absolute_error: 0.0914 - val_loss: 0.1066 - val_mean_absolute_error: 0.1107
# Epoch 77/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0709 - mean_absolute_error: 0.0911 - val_loss: 0.1058 - val_mean_absolute_error: 0.1112
# Epoch 78/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0707 - mean_absolute_error: 0.0909 - val_loss: 0.1050 - val_mean_absolute_error: 0.1118
# Epoch 79/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0704 - mean_absolute_error: 0.0906 - val_loss: 0.1041 - val_mean_absolute_error: 0.1126
# Epoch 80/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0702 - mean_absolute_error: 0.0904 - val_loss: 0.1035 - val_mean_absolute_error: 0.1134
# Epoch 81/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0700 - mean_absolute_error: 0.0901 - val_loss: 0.1031 - val_mean_absolute_error: 0.1143
# Epoch 82/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0699 - mean_absolute_error: 0.0899 - val_loss: 0.1019 - val_mean_absolute_error: 0.1143
# Epoch 83/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0696 - mean_absolute_error: 0.0896 - val_loss: 0.1006 - val_mean_absolute_error: 0.1141
# Epoch 84/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0693 - mean_absolute_error: 0.0894 - val_loss: 0.0996 - val_mean_absolute_error: 0.1148
# Epoch 85/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0692 - mean_absolute_error: 0.0892 - val_loss: 0.0988 - val_mean_absolute_error: 0.1158
# Epoch 86/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0690 - mean_absolute_error: 0.0889 - val_loss: 0.0979 - val_mean_absolute_error: 0.1156
# Epoch 87/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0687 - mean_absolute_error: 0.0887 - val_loss: 0.0971 - val_mean_absolute_error: 0.1162
# Epoch 88/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0685 - mean_absolute_error: 0.0886 - val_loss: 0.0966 - val_mean_absolute_error: 0.1171
# Epoch 89/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0685 - mean_absolute_error: 0.0883 - val_loss: 0.0955 - val_mean_absolute_error: 0.1163
# Epoch 90/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0681 - mean_absolute_error: 0.0882 - val_loss: 0.0941 - val_mean_absolute_error: 0.1166
# Epoch 91/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0679 - mean_absolute_error: 0.0880 - val_loss: 0.0933 - val_mean_absolute_error: 0.1170
# Epoch 92/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0678 - mean_absolute_error: 0.0878 - val_loss: 0.0923 - val_mean_absolute_error: 0.1169
# Epoch 93/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0676 - mean_absolute_error: 0.0876 - val_loss: 0.0915 - val_mean_absolute_error: 0.1169
# Epoch 94/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0673 - mean_absolute_error: 0.0874 - val_loss: 0.0907 - val_mean_absolute_error: 0.1172
# Epoch 95/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0671 - mean_absolute_error: 0.0871 - val_loss: 0.0900 - val_mean_absolute_error: 0.1171
# Epoch 96/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0670 - mean_absolute_error: 0.0868 - val_loss: 0.0896 - val_mean_absolute_error: 0.1170
# Epoch 97/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0669 - mean_absolute_error: 0.0865 - val_loss: 0.0888 - val_mean_absolute_error: 0.1169
# Epoch 98/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0666 - mean_absolute_error: 0.0863 - val_loss: 0.0885 - val_mean_absolute_error: 0.1174
# Epoch 99/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0665 - mean_absolute_error: 0.0861 - val_loss: 0.0881 - val_mean_absolute_error: 0.1180
# Epoch 100/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0663 - mean_absolute_error: 0.0859 - val_loss: 0.0867 - val_mean_absolute_error: 0.1169
# Epoch 101/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0662 - mean_absolute_error: 0.0857 - val_loss: 0.0868 - val_mean_absolute_error: 0.1177
# Epoch 102/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0660 - mean_absolute_error: 0.0856 - val_loss: 0.0863 - val_mean_absolute_error: 0.1180
# Epoch 103/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0659 - mean_absolute_error: 0.0854 - val_loss: 0.0849 - val_mean_absolute_error: 0.1170
# Epoch 104/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0657 - mean_absolute_error: 0.0853 - val_loss: 0.0849 - val_mean_absolute_error: 0.1173
# Epoch 105/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0656 - mean_absolute_error: 0.0852 - val_loss: 0.0834 - val_mean_absolute_error: 0.1163
# Epoch 106/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0655 - mean_absolute_error: 0.0850 - val_loss: 0.0827 - val_mean_absolute_error: 0.1159
# Epoch 107/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0653 - mean_absolute_error: 0.0849 - val_loss: 0.0827 - val_mean_absolute_error: 0.1168
# Epoch 108/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0652 - mean_absolute_error: 0.0847 - val_loss: 0.0820 - val_mean_absolute_error: 0.1168
# Epoch 109/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0651 - mean_absolute_error: 0.0846 - val_loss: 0.0814 - val_mean_absolute_error: 0.1166
# Epoch 110/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0650 - mean_absolute_error: 0.0845 - val_loss: 0.0809 - val_mean_absolute_error: 0.1166
# Epoch 111/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0649 - mean_absolute_error: 0.0844 - val_loss: 0.0807 - val_mean_absolute_error: 0.1170
# Epoch 112/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0648 - mean_absolute_error: 0.0842 - val_loss: 0.0805 - val_mean_absolute_error: 0.1176
# Epoch 113/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0647 - mean_absolute_error: 0.0841 - val_loss: 0.0794 - val_mean_absolute_error: 0.1169
# Epoch 114/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0646 - mean_absolute_error: 0.0840 - val_loss: 0.0790 - val_mean_absolute_error: 0.1163
# Epoch 115/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0645 - mean_absolute_error: 0.0839 - val_loss: 0.0784 - val_mean_absolute_error: 0.1162
# Epoch 116/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0644 - mean_absolute_error: 0.0837 - val_loss: 0.0778 - val_mean_absolute_error: 0.1155
# Epoch 117/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0643 - mean_absolute_error: 0.0836 - val_loss: 0.0771 - val_mean_absolute_error: 0.1151
# Epoch 118/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0643 - mean_absolute_error: 0.0835 - val_loss: 0.0764 - val_mean_absolute_error: 0.1149
# Epoch 119/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0642 - mean_absolute_error: 0.0834 - val_loss: 0.0754 - val_mean_absolute_error: 0.1139
# Epoch 120/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0641 - mean_absolute_error: 0.0833 - val_loss: 0.0748 - val_mean_absolute_error: 0.1136
# Epoch 121/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0640 - mean_absolute_error: 0.0832 - val_loss: 0.0739 - val_mean_absolute_error: 0.1128
# Epoch 122/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0639 - mean_absolute_error: 0.0832 - val_loss: 0.0728 - val_mean_absolute_error: 0.1120
# Epoch 123/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0639 - mean_absolute_error: 0.0832 - val_loss: 0.0732 - val_mean_absolute_error: 0.1134
# Epoch 124/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0638 - mean_absolute_error: 0.0830 - val_loss: 0.0720 - val_mean_absolute_error: 0.1123
# Epoch 125/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0637 - mean_absolute_error: 0.0830 - val_loss: 0.0724 - val_mean_absolute_error: 0.1129
# Epoch 126/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0636 - mean_absolute_error: 0.0829 - val_loss: 0.0712 - val_mean_absolute_error: 0.1119
# Epoch 127/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0636 - mean_absolute_error: 0.0829 - val_loss: 0.0711 - val_mean_absolute_error: 0.1125
# Epoch 128/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0635 - mean_absolute_error: 0.0828 - val_loss: 0.0697 - val_mean_absolute_error: 0.1111
# Epoch 129/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0634 - mean_absolute_error: 0.0828 - val_loss: 0.0697 - val_mean_absolute_error: 0.1114
# Epoch 130/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0633 - mean_absolute_error: 0.0828 - val_loss: 0.0706 - val_mean_absolute_error: 0.1127
# Epoch 131/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0633 - mean_absolute_error: 0.0827 - val_loss: 0.0693 - val_mean_absolute_error: 0.1118
# Epoch 132/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0632 - mean_absolute_error: 0.0826 - val_loss: 0.0700 - val_mean_absolute_error: 0.1125
# Epoch 133/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0631 - mean_absolute_error: 0.0826 - val_loss: 0.0703 - val_mean_absolute_error: 0.1128
# Epoch 134/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0632 - mean_absolute_error: 0.0826 - val_loss: 0.0682 - val_mean_absolute_error: 0.1109
# Epoch 135/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0630 - mean_absolute_error: 0.0825 - val_loss: 0.0684 - val_mean_absolute_error: 0.1111
# Epoch 136/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0629 - mean_absolute_error: 0.0825 - val_loss: 0.0685 - val_mean_absolute_error: 0.1112
# Epoch 137/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0630 - mean_absolute_error: 0.0824 - val_loss: 0.0673 - val_mean_absolute_error: 0.1110
# Epoch 138/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0628 - mean_absolute_error: 0.0824 - val_loss: 0.0677 - val_mean_absolute_error: 0.1110
# Epoch 139/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0628 - mean_absolute_error: 0.0825 - val_loss: 0.0667 - val_mean_absolute_error: 0.1101
# Epoch 140/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0627 - mean_absolute_error: 0.0823 - val_loss: 0.0674 - val_mean_absolute_error: 0.1114
# Epoch 141/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0626 - mean_absolute_error: 0.0822 - val_loss: 0.0661 - val_mean_absolute_error: 0.1100
# Epoch 142/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0626 - mean_absolute_error: 0.0822 - val_loss: 0.0652 - val_mean_absolute_error: 0.1090
# Epoch 143/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0625 - mean_absolute_error: 0.0822 - val_loss: 0.0654 - val_mean_absolute_error: 0.1097
# Epoch 144/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0625 - mean_absolute_error: 0.0821 - val_loss: 0.0636 - val_mean_absolute_error: 0.1078
# Epoch 145/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0624 - mean_absolute_error: 0.0822 - val_loss: 0.0641 - val_mean_absolute_error: 0.1087
# Epoch 146/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0624 - mean_absolute_error: 0.0821 - val_loss: 0.0630 - val_mean_absolute_error: 0.1079
# Epoch 147/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0623 - mean_absolute_error: 0.0820 - val_loss: 0.0611 - val_mean_absolute_error: 0.1053
# Epoch 148/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0622 - mean_absolute_error: 0.0821 - val_loss: 0.0623 - val_mean_absolute_error: 0.1071
# Epoch 149/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0622 - mean_absolute_error: 0.0820 - val_loss: 0.0609 - val_mean_absolute_error: 0.1060
# Epoch 150/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0621 - mean_absolute_error: 0.0820 - val_loss: 0.0606 - val_mean_absolute_error: 0.1055
# Epoch 151/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0620 - mean_absolute_error: 0.0819 - val_loss: 0.0611 - val_mean_absolute_error: 0.1063
# Epoch 152/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0620 - mean_absolute_error: 0.0820 - val_loss: 0.0614 - val_mean_absolute_error: 0.1067
# Epoch 153/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0619 - mean_absolute_error: 0.0820 - val_loss: 0.0608 - val_mean_absolute_error: 0.1061
# Epoch 154/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0619 - mean_absolute_error: 0.0819 - val_loss: 0.0610 - val_mean_absolute_error: 0.1070
# Epoch 155/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0619 - mean_absolute_error: 0.0819 - val_loss: 0.0599 - val_mean_absolute_error: 0.1058
# Epoch 156/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0618 - mean_absolute_error: 0.0819 - val_loss: 0.0578 - val_mean_absolute_error: 0.1033
# Epoch 157/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0617 - mean_absolute_error: 0.0819 - val_loss: 0.0579 - val_mean_absolute_error: 0.1039
# Epoch 158/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0617 - mean_absolute_error: 0.0819 - val_loss: 0.0584 - val_mean_absolute_error: 0.1053
# Epoch 159/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0617 - mean_absolute_error: 0.0818 - val_loss: 0.0559 - val_mean_absolute_error: 0.1021
# Epoch 160/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0616 - mean_absolute_error: 0.0819 - val_loss: 0.0568 - val_mean_absolute_error: 0.1034
# Epoch 161/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0616 - mean_absolute_error: 0.0818 - val_loss: 0.0571 - val_mean_absolute_error: 0.1046
# Epoch 162/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0615 - mean_absolute_error: 0.0817 - val_loss: 0.0557 - val_mean_absolute_error: 0.1025
# Epoch 163/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0614 - mean_absolute_error: 0.0817 - val_loss: 0.0564 - val_mean_absolute_error: 0.1033
# Epoch 164/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0614 - mean_absolute_error: 0.0816 - val_loss: 0.0551 - val_mean_absolute_error: 0.1021
# Epoch 165/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0613 - mean_absolute_error: 0.0816 - val_loss: 0.0548 - val_mean_absolute_error: 0.1018
# Epoch 166/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0613 - mean_absolute_error: 0.0815 - val_loss: 0.0536 - val_mean_absolute_error: 0.1005
# Epoch 167/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0612 - mean_absolute_error: 0.0816 - val_loss: 0.0533 - val_mean_absolute_error: 0.1002
# Epoch 168/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0612 - mean_absolute_error: 0.0816 - val_loss: 0.0534 - val_mean_absolute_error: 0.1006
# Epoch 169/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0611 - mean_absolute_error: 0.0814 - val_loss: 0.0534 - val_mean_absolute_error: 0.1013
# Epoch 170/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0611 - mean_absolute_error: 0.0816 - val_loss: 0.0514 - val_mean_absolute_error: 0.0988
# Epoch 171/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0610 - mean_absolute_error: 0.0815 - val_loss: 0.0513 - val_mean_absolute_error: 0.0988
# Epoch 172/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0610 - mean_absolute_error: 0.0814 - val_loss: 0.0514 - val_mean_absolute_error: 0.0989
# Epoch 173/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0609 - mean_absolute_error: 0.0813 - val_loss: 0.0504 - val_mean_absolute_error: 0.0980
# Epoch 174/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0609 - mean_absolute_error: 0.0814 - val_loss: 0.0517 - val_mean_absolute_error: 0.0997
# Epoch 175/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0608 - mean_absolute_error: 0.0815 - val_loss: 0.0500 - val_mean_absolute_error: 0.0975
# Epoch 176/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0608 - mean_absolute_error: 0.0814 - val_loss: 0.0497 - val_mean_absolute_error: 0.0981
# Epoch 177/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0607 - mean_absolute_error: 0.0813 - val_loss: 0.0494 - val_mean_absolute_error: 0.0984
# Epoch 178/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0607 - mean_absolute_error: 0.0814 - val_loss: 0.0484 - val_mean_absolute_error: 0.0966
# Epoch 179/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0607 - mean_absolute_error: 0.0814 - val_loss: 0.0485 - val_mean_absolute_error: 0.0967
# Epoch 180/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0606 - mean_absolute_error: 0.0814 - val_loss: 0.0475 - val_mean_absolute_error: 0.0955
# Epoch 181/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0606 - mean_absolute_error: 0.0813 - val_loss: 0.0479 - val_mean_absolute_error: 0.0965
# Epoch 182/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0606 - mean_absolute_error: 0.0814 - val_loss: 0.0464 - val_mean_absolute_error: 0.0951
# Epoch 183/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0605 - mean_absolute_error: 0.0813 - val_loss: 0.0466 - val_mean_absolute_error: 0.0955
# Epoch 184/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0605 - mean_absolute_error: 0.0813 - val_loss: 0.0450 - val_mean_absolute_error: 0.0935
# Epoch 185/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0604 - mean_absolute_error: 0.0812 - val_loss: 0.0463 - val_mean_absolute_error: 0.0951
# Epoch 186/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0603 - mean_absolute_error: 0.0812 - val_loss: 0.0477 - val_mean_absolute_error: 0.0971
# Epoch 187/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0604 - mean_absolute_error: 0.0811 - val_loss: 0.0446 - val_mean_absolute_error: 0.0933
# Epoch 188/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0603 - mean_absolute_error: 0.0813 - val_loss: 0.0430 - val_mean_absolute_error: 0.0912
# Epoch 189/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0602 - mean_absolute_error: 0.0810 - val_loss: 0.0459 - val_mean_absolute_error: 0.0955
# Epoch 190/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0602 - mean_absolute_error: 0.0811 - val_loss: 0.0460 - val_mean_absolute_error: 0.0953
# Epoch 191/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0601 - mean_absolute_error: 0.0810 - val_loss: 0.0453 - val_mean_absolute_error: 0.0951
# Epoch 192/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0601 - mean_absolute_error: 0.0811 - val_loss: 0.0430 - val_mean_absolute_error: 0.0921
# Epoch 193/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0600 - mean_absolute_error: 0.0811 - val_loss: 0.0414 - val_mean_absolute_error: 0.0900
# Epoch 194/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0600 - mean_absolute_error: 0.0813 - val_loss: 0.0442 - val_mean_absolute_error: 0.0931
# Epoch 195/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0600 - mean_absolute_error: 0.0810 - val_loss: 0.0445 - val_mean_absolute_error: 0.0953
# Epoch 196/500
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0600 - mean_absolute_error: 0.0811 - val_loss: 0.0414 - val_mean_absolute_error: 0.0911
# Epoch 197/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0599 - mean_absolute_error: 0.0811 - val_loss: 0.0394 - val_mean_absolute_error: 0.0879
# Epoch 198/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0599 - mean_absolute_error: 0.0812 - val_loss: 0.0401 - val_mean_absolute_error: 0.0883
# Epoch 199/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0598 - mean_absolute_error: 0.0809 - val_loss: 0.0435 - val_mean_absolute_error: 0.0939
# Epoch 200/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0598 - mean_absolute_error: 0.0810 - val_loss: 0.0414 - val_mean_absolute_error: 0.0915
# Epoch 201/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0598 - mean_absolute_error: 0.0810 - val_loss: 0.0390 - val_mean_absolute_error: 0.0877
# Epoch 202/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0597 - mean_absolute_error: 0.0811 - val_loss: 0.0384 - val_mean_absolute_error: 0.0862
# Epoch 203/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0596 - mean_absolute_error: 0.0809 - val_loss: 0.0389 - val_mean_absolute_error: 0.0878
# Epoch 204/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0596 - mean_absolute_error: 0.0810 - val_loss: 0.0396 - val_mean_absolute_error: 0.0880
# Epoch 205/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0596 - mean_absolute_error: 0.0809 - val_loss: 0.0384 - val_mean_absolute_error: 0.0874
# Epoch 206/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0596 - mean_absolute_error: 0.0811 - val_loss: 0.0377 - val_mean_absolute_error: 0.0862
# Epoch 207/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0595 - mean_absolute_error: 0.0809 - val_loss: 0.0378 - val_mean_absolute_error: 0.0864
# Epoch 208/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0595 - mean_absolute_error: 0.0809 - val_loss: 0.0375 - val_mean_absolute_error: 0.0860
# Epoch 209/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0594 - mean_absolute_error: 0.0809 - val_loss: 0.0377 - val_mean_absolute_error: 0.0864
# Epoch 210/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0594 - mean_absolute_error: 0.0810 - val_loss: 0.0365 - val_mean_absolute_error: 0.0844
# Epoch 211/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0593 - mean_absolute_error: 0.0808 - val_loss: 0.0371 - val_mean_absolute_error: 0.0859
# Epoch 212/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0593 - mean_absolute_error: 0.0810 - val_loss: 0.0368 - val_mean_absolute_error: 0.0853
# Epoch 213/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0593 - mean_absolute_error: 0.0808 - val_loss: 0.0366 - val_mean_absolute_error: 0.0854
# Epoch 214/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0593 - mean_absolute_error: 0.0809 - val_loss: 0.0356 - val_mean_absolute_error: 0.0842
# Epoch 215/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0592 - mean_absolute_error: 0.0810 - val_loss: 0.0356 - val_mean_absolute_error: 0.0836
# Epoch 216/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0591 - mean_absolute_error: 0.0808 - val_loss: 0.0367 - val_mean_absolute_error: 0.0859
# Epoch 217/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0592 - mean_absolute_error: 0.0808 - val_loss: 0.0346 - val_mean_absolute_error: 0.0832
# Epoch 218/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0591 - mean_absolute_error: 0.0808 - val_loss: 0.0351 - val_mean_absolute_error: 0.0833
# Epoch 219/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0591 - mean_absolute_error: 0.0808 - val_loss: 0.0357 - val_mean_absolute_error: 0.0849
# Epoch 220/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0591 - mean_absolute_error: 0.0809 - val_loss: 0.0347 - val_mean_absolute_error: 0.0828
# Epoch 221/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0589 - mean_absolute_error: 0.0807 - val_loss: 0.0365 - val_mean_absolute_error: 0.0855
# Epoch 222/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0590 - mean_absolute_error: 0.0807 - val_loss: 0.0342 - val_mean_absolute_error: 0.0829
# Epoch 223/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0590 - mean_absolute_error: 0.0807 - val_loss: 0.0338 - val_mean_absolute_error: 0.0818
# Epoch 224/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0589 - mean_absolute_error: 0.0808 - val_loss: 0.0347 - val_mean_absolute_error: 0.0829
# Epoch 225/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0589 - mean_absolute_error: 0.0805 - val_loss: 0.0342 - val_mean_absolute_error: 0.0829
# Epoch 226/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0589 - mean_absolute_error: 0.0806 - val_loss: 0.0323 - val_mean_absolute_error: 0.0802
# Epoch 227/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0588 - mean_absolute_error: 0.0806 - val_loss: 0.0334 - val_mean_absolute_error: 0.0815
# Epoch 228/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0588 - mean_absolute_error: 0.0807 - val_loss: 0.0336 - val_mean_absolute_error: 0.0818
# Epoch 229/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0586 - mean_absolute_error: 0.0804 - val_loss: 0.0347 - val_mean_absolute_error: 0.0837
# Epoch 230/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0587 - mean_absolute_error: 0.0805 - val_loss: 0.0330 - val_mean_absolute_error: 0.0812
# Epoch 231/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0586 - mean_absolute_error: 0.0804 - val_loss: 0.0335 - val_mean_absolute_error: 0.0819
# Epoch 232/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0587 - mean_absolute_error: 0.0805 - val_loss: 0.0326 - val_mean_absolute_error: 0.0800
# Epoch 233/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0585 - mean_absolute_error: 0.0803 - val_loss: 0.0327 - val_mean_absolute_error: 0.0812
# Epoch 234/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0585 - mean_absolute_error: 0.0806 - val_loss: 0.0334 - val_mean_absolute_error: 0.0819
# Epoch 235/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0585 - mean_absolute_error: 0.0803 - val_loss: 0.0323 - val_mean_absolute_error: 0.0807
# Epoch 236/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0585 - mean_absolute_error: 0.0805 - val_loss: 0.0320 - val_mean_absolute_error: 0.0803
# Epoch 237/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0584 - mean_absolute_error: 0.0804 - val_loss: 0.0324 - val_mean_absolute_error: 0.0808
# Epoch 238/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0584 - mean_absolute_error: 0.0804 - val_loss: 0.0323 - val_mean_absolute_error: 0.0807
# Epoch 239/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0583 - mean_absolute_error: 0.0802 - val_loss: 0.0318 - val_mean_absolute_error: 0.0802
# Epoch 240/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0583 - mean_absolute_error: 0.0805 - val_loss: 0.0341 - val_mean_absolute_error: 0.0833
# Epoch 241/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0583 - mean_absolute_error: 0.0802 - val_loss: 0.0310 - val_mean_absolute_error: 0.0789
# Epoch 242/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0583 - mean_absolute_error: 0.0803 - val_loss: 0.0325 - val_mean_absolute_error: 0.0813
# Epoch 243/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0581 - mean_absolute_error: 0.0803 - val_loss: 0.0326 - val_mean_absolute_error: 0.0810
# Epoch 244/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0582 - mean_absolute_error: 0.0804 - val_loss: 0.0327 - val_mean_absolute_error: 0.0816
# Epoch 245/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0582 - mean_absolute_error: 0.0801 - val_loss: 0.0319 - val_mean_absolute_error: 0.0804
# Epoch 246/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0582 - mean_absolute_error: 0.0803 - val_loss: 0.0320 - val_mean_absolute_error: 0.0803
# Epoch 247/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0580 - mean_absolute_error: 0.0802 - val_loss: 0.0315 - val_mean_absolute_error: 0.0803
# Epoch 248/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0580 - mean_absolute_error: 0.0804 - val_loss: 0.0312 - val_mean_absolute_error: 0.0793
# Epoch 249/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0580 - mean_absolute_error: 0.0801 - val_loss: 0.0325 - val_mean_absolute_error: 0.0810
# Epoch 250/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0580 - mean_absolute_error: 0.0802 - val_loss: 0.0314 - val_mean_absolute_error: 0.0796
# Epoch 251/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0578 - mean_absolute_error: 0.0801 - val_loss: 0.0335 - val_mean_absolute_error: 0.0829
# Epoch 252/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0579 - mean_absolute_error: 0.0800 - val_loss: 0.0318 - val_mean_absolute_error: 0.0800
# Epoch 253/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0578 - mean_absolute_error: 0.0801 - val_loss: 0.0321 - val_mean_absolute_error: 0.0807
# Epoch 254/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0579 - mean_absolute_error: 0.0801 - val_loss: 0.0313 - val_mean_absolute_error: 0.0799
# Epoch 255/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0578 - mean_absolute_error: 0.0801 - val_loss: 0.0331 - val_mean_absolute_error: 0.0818
# Epoch 256/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0578 - mean_absolute_error: 0.0800 - val_loss: 0.0320 - val_mean_absolute_error: 0.0805
# Epoch 257/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0578 - mean_absolute_error: 0.0801 - val_loss: 0.0306 - val_mean_absolute_error: 0.0787
# Epoch 258/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0577 - mean_absolute_error: 0.0800 - val_loss: 0.0337 - val_mean_absolute_error: 0.0837
# Epoch 259/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0577 - mean_absolute_error: 0.0800 - val_loss: 0.0317 - val_mean_absolute_error: 0.0804
# Epoch 260/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0576 - mean_absolute_error: 0.0800 - val_loss: 0.0332 - val_mean_absolute_error: 0.0831
# Epoch 261/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0576 - mean_absolute_error: 0.0799 - val_loss: 0.0313 - val_mean_absolute_error: 0.0798
# Epoch 262/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0576 - mean_absolute_error: 0.0800 - val_loss: 0.0347 - val_mean_absolute_error: 0.0853
# Epoch 263/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0575 - mean_absolute_error: 0.0799 - val_loss: 0.0309 - val_mean_absolute_error: 0.0789
# Epoch 264/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0575 - mean_absolute_error: 0.0800 - val_loss: 0.0325 - val_mean_absolute_error: 0.0819
# Epoch 265/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0575 - mean_absolute_error: 0.0800 - val_loss: 0.0303 - val_mean_absolute_error: 0.0795
# Epoch 266/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0574 - mean_absolute_error: 0.0799 - val_loss: 0.0324 - val_mean_absolute_error: 0.0813
# Epoch 267/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0575 - mean_absolute_error: 0.0798 - val_loss: 0.0330 - val_mean_absolute_error: 0.0818
# Epoch 268/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0573 - mean_absolute_error: 0.0799 - val_loss: 0.0330 - val_mean_absolute_error: 0.0815
# Epoch 269/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0573 - mean_absolute_error: 0.0799 - val_loss: 0.0331 - val_mean_absolute_error: 0.0822
# Epoch 270/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0573 - mean_absolute_error: 0.0799 - val_loss: 0.0327 - val_mean_absolute_error: 0.0816
# Epoch 271/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0572 - mean_absolute_error: 0.0798 - val_loss: 0.0334 - val_mean_absolute_error: 0.0822
# Epoch 272/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0572 - mean_absolute_error: 0.0799 - val_loss: 0.0333 - val_mean_absolute_error: 0.0826
# Epoch 273/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0572 - mean_absolute_error: 0.0798 - val_loss: 0.0323 - val_mean_absolute_error: 0.0806
# Epoch 274/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0571 - mean_absolute_error: 0.0798 - val_loss: 0.0330 - val_mean_absolute_error: 0.0818
# Epoch 275/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0571 - mean_absolute_error: 0.0799 - val_loss: 0.0320 - val_mean_absolute_error: 0.0802
# Epoch 276/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0571 - mean_absolute_error: 0.0798 - val_loss: 0.0346 - val_mean_absolute_error: 0.0836
# Epoch 277/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0570 - mean_absolute_error: 0.0796 - val_loss: 0.0330 - val_mean_absolute_error: 0.0821
# Epoch 278/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0571 - mean_absolute_error: 0.0799 - val_loss: 0.0322 - val_mean_absolute_error: 0.0798
# Epoch 279/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0570 - mean_absolute_error: 0.0797 - val_loss: 0.0323 - val_mean_absolute_error: 0.0809
# Epoch 280/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0570 - mean_absolute_error: 0.0798 - val_loss: 0.0309 - val_mean_absolute_error: 0.0794
# Epoch 281/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0570 - mean_absolute_error: 0.0798 - val_loss: 0.0325 - val_mean_absolute_error: 0.0804
# Epoch 282/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0569 - mean_absolute_error: 0.0795 - val_loss: 0.0323 - val_mean_absolute_error: 0.0806
# Epoch 283/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0569 - mean_absolute_error: 0.0797 - val_loss: 0.0317 - val_mean_absolute_error: 0.0786
# Epoch 284/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0569 - mean_absolute_error: 0.0798 - val_loss: 0.0317 - val_mean_absolute_error: 0.0800
# Epoch 285/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0568 - mean_absolute_error: 0.0796 - val_loss: 0.0314 - val_mean_absolute_error: 0.0803
# Epoch 286/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0568 - mean_absolute_error: 0.0797 - val_loss: 0.0316 - val_mean_absolute_error: 0.0789
# Epoch 287/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0568 - mean_absolute_error: 0.0796 - val_loss: 0.0311 - val_mean_absolute_error: 0.0783
# Epoch 288/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0567 - mean_absolute_error: 0.0796 - val_loss: 0.0304 - val_mean_absolute_error: 0.0777
# Epoch 289/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0566 - mean_absolute_error: 0.0797 - val_loss: 0.0307 - val_mean_absolute_error: 0.0787
# Epoch 290/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0568 - mean_absolute_error: 0.0800 - val_loss: 0.0299 - val_mean_absolute_error: 0.0765
# Epoch 291/500
# ...
# Epoch 338/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0531 - mean_absolute_error: 0.0794 - val_loss: 0.0182 - val_mean_absolute_error: 0.0549
# Epoch 339/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0532 - mean_absolute_error: 0.0795 - val_loss: 0.0169 - val_mean_absolute_error: 0.0562
# Epoch 340/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0532 - mean_absolute_error: 0.0794 - val_loss: 0.0122 - val_mean_absolute_error: 0.0489
# Epoch 341/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0535 - mean_absolute_error: 0.0803 - val_loss: 0.0106 - val_mean_absolute_error: 0.0433
# Epoch 342/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0530 - mean_absolute_error: 0.0793 - val_loss: 0.0106 - val_mean_absolute_error: 0.0419
# Epoch 343/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0528 - mean_absolute_error: 0.0789 - val_loss: 0.0130 - val_mean_absolute_error: 0.0469
# Epoch 344/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0526 - mean_absolute_error: 0.0788 - val_loss: 0.0135 - val_mean_absolute_error: 0.0477
# Epoch 345/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0526 - mean_absolute_error: 0.0785 - val_loss: 0.0156 - val_mean_absolute_error: 0.0550
# Epoch 346/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0530 - mean_absolute_error: 0.0784 - val_loss: 0.0109 - val_mean_absolute_error: 0.0416
# Epoch 347/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0530 - mean_absolute_error: 0.0787 - val_loss: 0.0092 - val_mean_absolute_error: 0.0375
# Epoch 348/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0529 - mean_absolute_error: 0.0789 - val_loss: 0.0089 - val_mean_absolute_error: 0.0356
# Epoch 349/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0525 - mean_absolute_error: 0.0787 - val_loss: 0.0098 - val_mean_absolute_error: 0.0391
# Epoch 350/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0521 - mean_absolute_error: 0.0781 - val_loss: 0.0109 - val_mean_absolute_error: 0.0407
# Epoch 351/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0521 - mean_absolute_error: 0.0782 - val_loss: 0.0107 - val_mean_absolute_error: 0.0400
# Epoch 352/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0523 - mean_absolute_error: 0.0783 - val_loss: 0.0097 - val_mean_absolute_error: 0.0370
# Epoch 353/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0522 - mean_absolute_error: 0.0784 - val_loss: 0.0098 - val_mean_absolute_error: 0.0377
# Epoch 354/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0524 - mean_absolute_error: 0.0785 - val_loss: 0.0090 - val_mean_absolute_error: 0.0363
# Epoch 355/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0526 - mean_absolute_error: 0.0787 - val_loss: 0.0075 - val_mean_absolute_error: 0.0336
# Epoch 356/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0526 - mean_absolute_error: 0.0785 - val_loss: 0.0074 - val_mean_absolute_error: 0.0328
# Epoch 357/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0521 - mean_absolute_error: 0.0785 - val_loss: 0.0089 - val_mean_absolute_error: 0.0359
# Epoch 358/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0517 - mean_absolute_error: 0.0783 - val_loss: 0.0095 - val_mean_absolute_error: 0.0371
# Epoch 359/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0515 - mean_absolute_error: 0.0780 - val_loss: 0.0082 - val_mean_absolute_error: 0.0336
# Epoch 360/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0516 - mean_absolute_error: 0.0779 - val_loss: 0.0070 - val_mean_absolute_error: 0.0325
# Epoch 361/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0520 - mean_absolute_error: 0.0783 - val_loss: 0.0069 - val_mean_absolute_error: 0.0333
# Epoch 362/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0521 - mean_absolute_error: 0.0786 - val_loss: 0.0070 - val_mean_absolute_error: 0.0334
# Epoch 363/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0518 - mean_absolute_error: 0.0783 - val_loss: 0.0075 - val_mean_absolute_error: 0.0336
# Epoch 364/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0514 - mean_absolute_error: 0.0781 - val_loss: 0.0072 - val_mean_absolute_error: 0.0335
# Epoch 365/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0513 - mean_absolute_error: 0.0780 - val_loss: 0.0068 - val_mean_absolute_error: 0.0336
# Epoch 366/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0515 - mean_absolute_error: 0.0783 - val_loss: 0.0064 - val_mean_absolute_error: 0.0320
# Epoch 367/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0515 - mean_absolute_error: 0.0785 - val_loss: 0.0065 - val_mean_absolute_error: 0.0342
# Epoch 368/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0515 - mean_absolute_error: 0.0783 - val_loss: 0.0061 - val_mean_absolute_error: 0.0333
# Epoch 369/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0516 - mean_absolute_error: 0.0787 - val_loss: 0.0061 - val_mean_absolute_error: 0.0330
# Epoch 370/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0517 - mean_absolute_error: 0.0788 - val_loss: 0.0059 - val_mean_absolute_error: 0.0339
# Epoch 371/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0518 - mean_absolute_error: 0.0786 - val_loss: 0.0059 - val_mean_absolute_error: 0.0329
# Epoch 372/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0515 - mean_absolute_error: 0.0790 - val_loss: 0.0067 - val_mean_absolute_error: 0.0362
# Epoch 373/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0512 - mean_absolute_error: 0.0791 - val_loss: 0.0065 - val_mean_absolute_error: 0.0351
# Epoch 374/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0512 - mean_absolute_error: 0.0792 - val_loss: 0.0073 - val_mean_absolute_error: 0.0388
# Epoch 375/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0508 - mean_absolute_error: 0.0789 - val_loss: 0.0067 - val_mean_absolute_error: 0.0361
# Epoch 376/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0509 - mean_absolute_error: 0.0790 - val_loss: 0.0067 - val_mean_absolute_error: 0.0371
# Epoch 377/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0510 - mean_absolute_error: 0.0786 - val_loss: 0.0068 - val_mean_absolute_error: 0.0362
# Epoch 378/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0510 - mean_absolute_error: 0.0784 - val_loss: 0.0084 - val_mean_absolute_error: 0.0413
# Epoch 379/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0511 - mean_absolute_error: 0.0785 - val_loss: 0.0082 - val_mean_absolute_error: 0.0401
# Epoch 380/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0512 - mean_absolute_error: 0.0782 - val_loss: 0.0079 - val_mean_absolute_error: 0.0397
# Epoch 381/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0514 - mean_absolute_error: 0.0784 - val_loss: 0.0062 - val_mean_absolute_error: 0.0351
# Epoch 382/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0516 - mean_absolute_error: 0.0782 - val_loss: 0.0067 - val_mean_absolute_error: 0.0345
# Epoch 383/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0508 - mean_absolute_error: 0.0783 - val_loss: 0.0074 - val_mean_absolute_error: 0.0371
# Epoch 384/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0503 - mean_absolute_error: 0.0776 - val_loss: 0.0070 - val_mean_absolute_error: 0.0358
# Epoch 385/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0501 - mean_absolute_error: 0.0776 - val_loss: 0.0069 - val_mean_absolute_error: 0.0348
# Epoch 386/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0499 - mean_absolute_error: 0.0774 - val_loss: 0.0072 - val_mean_absolute_error: 0.0368
# Epoch 387/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0499 - mean_absolute_error: 0.0776 - val_loss: 0.0076 - val_mean_absolute_error: 0.0384
# Epoch 388/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0505 - mean_absolute_error: 0.0785 - val_loss: 0.0092 - val_mean_absolute_error: 0.0425
# Epoch 389/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0508 - mean_absolute_error: 0.0793 - val_loss: 0.0107 - val_mean_absolute_error: 0.0476
# Epoch 390/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0513 - mean_absolute_error: 0.0802 - val_loss: 0.0153 - val_mean_absolute_error: 0.0545
# Epoch 391/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0509 - mean_absolute_error: 0.0807 - val_loss: 0.0126 - val_mean_absolute_error: 0.0536
# Epoch 392/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0515 - mean_absolute_error: 0.0805 - val_loss: 0.0082 - val_mean_absolute_error: 0.0432
# Epoch 393/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0517 - mean_absolute_error: 0.0801 - val_loss: 0.0055 - val_mean_absolute_error: 0.0332
# Epoch 394/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0511 - mean_absolute_error: 0.0794 - val_loss: 0.0051 - val_mean_absolute_error: 0.0297
# Epoch 395/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0514 - mean_absolute_error: 0.0788 - val_loss: 0.0074 - val_mean_absolute_error: 0.0357
# Epoch 396/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0509 - mean_absolute_error: 0.0792 - val_loss: 0.0074 - val_mean_absolute_error: 0.0354
# Epoch 397/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0503 - mean_absolute_error: 0.0787 - val_loss: 0.0108 - val_mean_absolute_error: 0.0432
# Epoch 398/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0497 - mean_absolute_error: 0.0791 - val_loss: 0.0110 - val_mean_absolute_error: 0.0435
# Epoch 399/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0507 - mean_absolute_error: 0.0787 - val_loss: 0.0189 - val_mean_absolute_error: 0.0563
# Epoch 400/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0520 - mean_absolute_error: 0.0800 - val_loss: 0.0107 - val_mean_absolute_error: 0.0484
# Epoch 401/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0528 - mean_absolute_error: 0.0802 - val_loss: 0.0190 - val_mean_absolute_error: 0.0615
# Epoch 402/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0517 - mean_absolute_error: 0.0795 - val_loss: 0.0090 - val_mean_absolute_error: 0.0430
# Epoch 403/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0518 - mean_absolute_error: 0.0789 - val_loss: 0.0050 - val_mean_absolute_error: 0.0317
# Epoch 404/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0525 - mean_absolute_error: 0.0788 - val_loss: 0.0145 - val_mean_absolute_error: 0.0519
# Epoch 405/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0512 - mean_absolute_error: 0.0790 - val_loss: 0.0116 - val_mean_absolute_error: 0.0409
# Epoch 406/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0502 - mean_absolute_error: 0.0778 - val_loss: 0.0130 - val_mean_absolute_error: 0.0441
# Epoch 407/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0492 - mean_absolute_error: 0.0772 - val_loss: 0.0125 - val_mean_absolute_error: 0.0452
# Epoch 408/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0507 - mean_absolute_error: 0.0768 - val_loss: 0.0203 - val_mean_absolute_error: 0.0598
# Epoch 409/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0507 - mean_absolute_error: 0.0780 - val_loss: 0.0160 - val_mean_absolute_error: 0.0551
# Epoch 410/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0501 - mean_absolute_error: 0.0783 - val_loss: 0.0111 - val_mean_absolute_error: 0.0457
# Epoch 411/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0504 - mean_absolute_error: 0.0776 - val_loss: 0.0071 - val_mean_absolute_error: 0.0386
# Epoch 412/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0507 - mean_absolute_error: 0.0781 - val_loss: 0.0076 - val_mean_absolute_error: 0.0380
# Epoch 413/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0499 - mean_absolute_error: 0.0770 - val_loss: 0.0101 - val_mean_absolute_error: 0.0435
# Epoch 414/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0492 - mean_absolute_error: 0.0777 - val_loss: 0.0126 - val_mean_absolute_error: 0.0471
# Epoch 415/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0492 - mean_absolute_error: 0.0772 - val_loss: 0.0129 - val_mean_absolute_error: 0.0465
# Epoch 416/500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0490 - mean_absolute_error: 0.0780 - val_loss: 0.0124 - val_mean_absolute_error: 0.0452
# Epoch 417/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0503 - mean_absolute_error: 0.0770 - val_loss: 0.0143 - val_mean_absolute_error: 0.0523
# Epoch 418/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0502 - mean_absolute_error: 0.0778 - val_loss: 0.0147 - val_mean_absolute_error: 0.0534
# Epoch 419/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0507 - mean_absolute_error: 0.0784 - val_loss: 0.0149 - val_mean_absolute_error: 0.0549
# Epoch 420/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0508 - mean_absolute_error: 0.0795 - val_loss: 0.0069 - val_mean_absolute_error: 0.0363
# Epoch 421/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0520 - mean_absolute_error: 0.0781 - val_loss: 0.0163 - val_mean_absolute_error: 0.0492
# Epoch 422/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0490 - mean_absolute_error: 0.0792 - val_loss: 0.0184 - val_mean_absolute_error: 0.0572
# Epoch 423/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0487 - mean_absolute_error: 0.0766 - val_loss: 0.0158 - val_mean_absolute_error: 0.0501
# Epoch 424/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0484 - mean_absolute_error: 0.0778 - val_loss: 0.0132 - val_mean_absolute_error: 0.0480
# Epoch 425/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0491 - mean_absolute_error: 0.0776 - val_loss: 0.0210 - val_mean_absolute_error: 0.0549
# Epoch 426/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0481 - mean_absolute_error: 0.0790 - val_loss: 0.0206 - val_mean_absolute_error: 0.0530
# Epoch 427/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0490 - mean_absolute_error: 0.0775 - val_loss: 0.0208 - val_mean_absolute_error: 0.0576
# Epoch 428/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0486 - mean_absolute_error: 0.0790 - val_loss: 0.0167 - val_mean_absolute_error: 0.0508
# Epoch 429/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0497 - mean_absolute_error: 0.0785 - val_loss: 0.0150 - val_mean_absolute_error: 0.0529
# Epoch 430/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0496 - mean_absolute_error: 0.0783 - val_loss: 0.0120 - val_mean_absolute_error: 0.0460
# Epoch 431/500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0498 - mean_absolute_error: 0.0780 - val_loss: 0.0104 - val_mean_absolute_error: 0.0459
# Epoch 432/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0495 - mean_absolute_error: 0.0776 - val_loss: 0.0082 - val_mean_absolute_error: 0.0390
# Epoch 433/500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0493 - mean_absolute_error: 0.0774 - val_loss: 0.0129 - val_mean_absolute_error: 0.0470

# %%
region = "Lombardia"
feature = "nuovi_positivi"  #nuovi_positivi, dimessi_guariti, #totale_ospedalizzati #deceduti
plot_feature(region, feature, multi_lstm_model, 30)

# THE MODEL DOES NOT LEARN NUOVI_POSITVI: I THINK IT'S BEACUSE THE OTHER FEATURES HAVE AN INCREASING AND A DECREASING TREND,
# AND THE NN IS CONFUSED. FIRST LET'S SEE IF PCT_CHANGE OR DIFF CHANGE SOMETHING ...
# Out:
# To view all the figures, increase max_figures

# %%
region = "Lombardia"

if VALIDATION:
    pred_x_predict = multi_lstm_model(np.array(val_df[reg].iloc[-IN_STEPS:,:]).reshape(1, IN_STEPS, 4)) 
    pred_x_predict
else:
    pred_x_predict = multi_lstm_model(np.array(train_df[reg].iloc[-IN_STEPS:,:]).reshape(1, IN_STEPS, 4))
    pred_x_predict

# %%
pr = tf.squeeze(pred_x_predict)
prd = pd.DataFrame(pr.numpy())

idx = test_df[reg].index[-OUT_STEPS:]

predictions = prd.rename(columns={0: 'pred_totale_ospedalizzati_' + reg, 
                                  1: 'pred_nuovi_positivi_' + reg,
                                  2: 'pred_dimessi_guariti_' + reg,
                                  3: 'pred_deceduti_' + reg},
                          index={ 0: idx[0],
                                  1: idx[1],
                                  2: idx[2],
                                  3: idx[3],
                                  4: idx[4],
                                  5: idx[5],
                                  6: idx[6]})

# %%
predictions
# Out:
#      pred_totale_ospedalizzati_Lombardia  pred_nuovi_positivi_Lombardia  \
# 281                             0.022212                       3.236684
# 282                            -0.023259                      -0.130181
# 283                            -0.006435                       0.096808
# 284                             0.010039                       0.041944
# 285                            -0.005345                       0.040588
# 286                             0.002235                      -0.145858
# 287                             0.030041                      -0.715118
#
#      pred_dimessi_guariti_Lombardia  pred_deceduti_Lombardia
# 281                        0.003271                -0.001216
# 282                        0.002267                 0.000819
# 283                        0.001030                -0.001608
# 284                        0.003269                -0.003493
# 285                        0.008262                 0.000353
# 286                       -0.006482                 0.000233
# 287                       -0.018409                -0.000557

# %%
test_df[reg]
# Out:
#      totale_ospedalizzati_Lombardia  nuovi_positivi_Lombardia  \
# 281                        0.026042                  0.442999
# 282                        0.021151                  5.039073
# 283                        0.023198                 -0.311909
# 284                        0.004049                 -0.049907
# 285                       -0.020161                 -0.073844
# 286                       -0.014815                 -0.298732
# 287                        0.013367                 -0.604990
#
#      dimessi_guariti_Lombardia  deceduti_Lombardia
# 281                   0.001417            0.000101
# 282                   0.005109            0.000605
# 283                   0.001742            0.000756
# 284                   0.006420            0.000907
# 285                   0.002835            0.001082
# 286                   0.002413            0.000578
# 287                   0.001984            0.000452

# %%
concatenated_df = pd.concat([predictions, test_df[reg]], axis=1)

errors = pd.DataFrame()
for i in range(4):
  errors = pd.concat([errors, concatenated_df.iloc[:, i] - concatenated_df.iloc[:, i+4]], axis = 1, ignore_index=True)

# %%
errors    #ordine: totale_ospedalizzati	nuovi_positivi	dimessi_guariti	deceduti
# Out:
#             0         1         2         3
# 281 -0.003830  2.793685  0.001854 -0.001317
# 282 -0.044410 -5.169254 -0.002842  0.000214
# 283 -0.029633  0.408717 -0.000712 -0.002364
# 284  0.005990  0.091851 -0.003151 -0.004399
# 285  0.014817  0.114433  0.005427 -0.000729
# 286  0.017050  0.152874 -0.008895 -0.000345
# 287  0.016674 -0.110128 -0.020393 -0.001009

# %%
# Nuovi positivi 

plt.scatter(predictions.index, predictions['pred_nuovi_positivi_Lombardia'], label = 'Predictions')
plt.scatter(predictions.index, test_df[reg].iloc[-OUT_STEPS:, 1], label = 'Data')
plt.legend()

# %%
# Totale ospedalizzati

plt.scatter(predictions.index, predictions['pred_totale_ospedalizzati_Lombardia'], label = 'Predictions')
plt.scatter(predictions.index, test_df[reg]['totale_ospedalizzati_Lombardia'], label = 'Data')
plt.legend()

# %%
# Dimessi guariti

plt.scatter(predictions.index, predictions['pred_dimessi_guariti_Lombardia'], label = 'Predictions')
plt.scatter(predictions.index, test_df[reg]['dimessi_guariti_Lombardia'], label = 'Data')
plt.legend()

# %%
# Deceduti 

plt.scatter(predictions.index, predictions['pred_deceduti_Lombardia'], label = 'Predictions')
plt.scatter(predictions.index, test_df[reg]['deceduti_Lombardia'], label = 'Data')
plt.legend()

# %%
prova = np.ones((IN_STEPS,4)).reshape(1,IN_STEPS,4)
multi_lstm_model.predict(prova)
# Out:
# array([[[-1.9495077e-03,  9.6818328e-02, -2.0028260e-02, -4.8601441e-03],
#         [-1.5853891e-02,  2.8634524e-01,  8.7463893e-03,  1.5898956e-02],
#         [-1.5500677e-02, -2.6591885e-01,  3.3794204e-04,  4.7133444e-03],
#         [-6.5649329e-03, -1.6868129e-01,  1.9951342e-02,  7.6810285e-03],
#         [ 4.9600517e-03,  2.5743893e-01,  9.5622987e-03,  2.1294670e-03],
#         [ 1.7090533e-03,  4.2442468e-01,  3.3227177e-03,  1.7429369e-02],
#         [-1.6338438e-02,  3.0123126e-02, -1.8525867e-02, -3.7676845e-02]]],
#       dtype=float32)

# %% [markdown]
# ### Back to original scale

# %%
init = df_by_region[reg].iloc[-time_steps_for_test-1,:]
init = pd.DataFrame(init).T

initial = init.rename(columns={'totale_ospedalizzati_' + reg: 'pred_totale_ospedalizzati_' + reg, 
                               'nuovi_positivi_' + reg: 'pred_nuovi_positivi_' + reg,
                               'dimessi_guariti_' + reg: 'pred_dimessi_guariti_' + reg,
                               'deceduti_' + reg: 'pred_deceduti_' + reg} )

pred_original_scale = (1 + predictions).cumprod() * initial.iloc[0,:]

# %%
# Error with original data

idx_true = df_by_region[reg].iloc[-time_steps_for_test:,:].index
idx_pred = pred_original_scale.index
true_test = df_by_region[reg].iloc[-time_steps_for_test:,:].rename(index={idx_true[0]: idx_pred[0], 
                                                                          idx_true[1]: idx_pred[1], 
                                                                          idx_true[2]: idx_pred[2], 
                                                                          idx_true[3]: idx_pred[3], 
                                                                          idx_true[4]: idx_pred[4], 
                                                                          idx_true[5]: idx_pred[5], 
                                                                          idx_true[6]: idx_pred[6]} )

original_concatenated_df = pd.concat([pred_original_scale, true_test], axis=1 )

original_errors = pd.DataFrame()
for i in range(4):
  original_errors = pd.concat([original_errors, original_concatenated_df.iloc[:, i] - original_concatenated_df.iloc[:, i+4]], axis = 1, ignore_index=True)
  
original_err = original_errors.rename(columns={0: 'totale_ospedalizzati_' + reg, 
                                               1: 'nuovi_positivi_' + reg,
                                               2: 'dimessi_guariti_' + reg,
                                               3: 'deceduti_' + reg} )

original_error = (original_err * std) + mean

original_error_perc = (original_error / true_test) * 100

# %%
original_error_perc
# Out:
#      totale_ospedalizzati_Lombardia  nuovi_positivi_Lombardia  \
# 281                       -0.373267                193.602736
# 282                       -4.706028                -57.711865
# 283                       -7.465822                -32.593305
# 284                       -6.913761                -26.076709
# 285                       -5.506157                -16.942988
# 286                       -3.870788                  1.163118
# 287                       -2.289076                -27.040857
#
#      dimessi_guariti_Lombardia  deceduti_Lombardia
# 281                   0.185179           -0.131703
# 282                  -0.098113           -0.110319
# 283                  -0.169078           -0.346275
# 284                  -0.481669           -0.784263
# 285                   0.056913           -0.856542
# 286                  -0.830967           -0.890711
# 287                  -2.849307           -0.990647

# %%
original_errors      # con lstm(32) e dropout = 0.1 + giorni 2021
# Out:
#              0            1              2            3
# 281  -4.330170  2521.429980  -34737.726996   -66.655681
# 282 -31.734528 -8125.015045  -17589.807127   276.875938
# 283 -51.632660 -4410.062639 -138124.125666    74.165693
# 284 -40.990326 -4270.881676 -226634.647514  -459.917305
# 285 -14.112213 -2817.266313 -281501.478188  -707.911451
# 286   3.393677 -1310.472834 -363786.735420 -2014.552837
# 287  19.615753   180.535167 -409223.542635 -4022.169093

# %%
original_errors    # con lstm(16) e dropout = 0.1 e activation function selu
# Out:
#              0            1              2            3
# 281  -4.330170  2521.429980  -34737.726996   -66.655681
# 282 -31.734528 -8125.015045  -17589.807127   276.875938
# 283 -51.632660 -4410.062639 -138124.125666    74.165693
# 284 -40.990326 -4270.881676 -226634.647514  -459.917305
# 285 -14.112213 -2817.266313 -281501.478188  -707.911451
# 286   3.393677 -1310.472834 -363786.735420 -2014.552837
# 287  19.615753   180.535167 -409223.542635 -4022.169093

# %%
original_errors  # con lstm(16) e dropout = 0.1
# Out:
#              0            1              2            3
# 281  -4.330170  2521.429980  -34737.726996   -66.655681
# 282 -31.734528 -8125.015045  -17589.807127   276.875938
# 283 -51.632660 -4410.062639 -138124.125666    74.165693
# 284 -40.990326 -4270.881676 -226634.647514  -459.917305
# 285 -14.112213 -2817.266313 -281501.478188  -707.911451
# 286   3.393677 -1310.472834 -363786.735420 -2014.552837
# 287  19.615753   180.535167 -409223.542635 -4022.169093

# %%
# nuovi_positivi    totale_ospedalizzati   dimessi_guariti    deceduti

plt.scatter(pred_original_scale.index, pred_original_scale['pred_nuovi_positivi_Lombardia'], label = 'Predictions')
plt.scatter(pred_original_scale.index, df_by_region[reg].iloc[-time_steps_for_test:,:]['nuovi_positivi_Lombardia'], label = 'Data')
plt.legend()

# %% [markdown]
# # Comments

# %% [markdown]
# The model is doing way better than yesterday (the key thing was to put shuffle=False in the creation of the training dataset). Two problems:
# - The network has issues to learn the behaviour of "nuovi_positivi" beacuse the trend is very oscillating. Applying the Savitzky-Golay filter the network performs quite well but has it still struggles.
# - IMPORTANT: Since the trend of "deceduti" and "dimessi_guariti" is increasing, we must use pct_change or diff in the model. Otherwise the model will learn to predict in [a,b] with a,b in R, but the next seven days will be surely greater than b!
