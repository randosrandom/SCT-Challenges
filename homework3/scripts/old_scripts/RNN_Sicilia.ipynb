# %% [markdown]
# # Preprocessing

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
import os
import datetime as dt

import copy
import IPython
import numpy as np
import pandas as pd
import seaborn as sns
import IPython.display
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt

from scipy.signal import savgol_filter

tf.keras.utils.set_random_seed(
    987654321
)

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False
# Out:
# 2022-04-29 09:17:26.351430: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-29 09:17:26.351468: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Macros
BY_ZONE = False # True if you want grouping by zones (Nord, Centro, Sud, Sardegna)
BY_REGION = True # True if you want to keep single regions

# %%
# File name
#file_path = "../Data/dpc-covid19-ita-regioni.csv"
file_path = '../Data/dpc-covid19-ita-regioni.csv'
features_list = ["totale_ospedalizzati", "nuovi_positivi", "dimessi_guariti", "deceduti"]

# Load data
df_all_total = pd.read_csv(
    file_path,
    usecols = ["data", "denominazione_regione", "nuovi_positivi", "totale_ospedalizzati", "dimessi_guariti", "deceduti"],
    parse_dates = True,
)

# Convert data coulumn
df_all_total["data"] = pd.to_datetime(df_all_total["data"]).dt.date

# Keep only latest data wrt cut_date
cut_date_4 = dt.date(2999, 4, 15)   #(2022,4,15) Provando a tener fuori Pasqua
cut_date_3 = dt.date(2022, 1, 10)   #(2022, 1, 10)
cut_date_2 = dt.date(2022, 1, 10)   #(2021, 12, 1)
cut_date_1 = dt.date(2021, 2, 1)    #(2021, 2, 1)  

df_all = df_all_total.loc[ ((df_all_total["data"] >= cut_date_1) & (df_all_total["data"] <= cut_date_2)) | ((df_all_total["data"] >= cut_date_3) & (df_all_total["data"] <= cut_date_4))]
df_all.shape
# Out:
# (9492, 6)

# %%
df_tot = pd.DataFrame()

if BY_REGION:
    
    df_by_region = dict() # dictionary containing data for each regione

    regions = list(df_all.loc[:,"denominazione_regione"].unique())
    
    for reg in regions:
        
        df_by_region[reg] = df_all.loc[df_all["denominazione_regione"] == reg]
        columns_={"totale_ospedalizzati": "totale_ospedalizzati_" + reg, 
                 "nuovi_positivi": "nuovi_positivi_" + reg, 
                 "dimessi_guariti" : "dimessi_guariti_" + reg, 
                 "deceduti": "deceduti_" + reg}
        df_by_region[reg].pop("denominazione_regione")
        df_by_region[reg] = df_by_region[reg].rename(columns = columns_)
        df_by_region[reg].set_index("data", inplace = True)
       
        if df_tot.shape[0] == 0:
            df_tot = df_by_region[reg].iloc[:,1:]
        else:
            df_tot = pd.concat([df_tot, df_by_region[reg].iloc[:,1:]], axis=1)

# %% [markdown]
#  # RNN

# %% [markdown]
# ## Tensorflow modified classes

# %%
# FUNCTIONALITIES

# Window generator
class WindowGenerator():
  def __init__(self, input_width, label_width, shift,
               train_df, val_df=None, test_df=None,
               label_columns=None, batch_size = 32):
    # Store the raw data.
    self.train_df = train_df
    self.val_df = val_df
    self.test_df = test_df
    self.batch_size = batch_size
    
    # Work out the label column indices.
    self.label_columns = label_columns
    if label_columns is not None:
      self.label_columns_indices = {name: i for i, name in
                                    enumerate(label_columns)}
    self.column_indices = {name: i for i, name in
                           enumerate(train_df.columns)}

    # Work out the window parameters.
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift

    self.total_window_size = input_width + shift

    self.input_slice = slice(0, input_width)
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]

    self.label_start = self.total_window_size - self.label_width
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

  def __repr__(self):
    return '\n'.join([
        f'Total window size: {self.total_window_size}',
        f'Input indices: {self.input_indices}',
        f'Label indices: {self.label_indices}',
        f'Label column name(s): {self.label_columns}'])

# Split window
def split_window(self, features):
  inputs = features[:, self.input_slice, :]
  labels = features[:, self.labels_slice, :]
  if self.label_columns is not None:
    labels = tf.stack(
        [labels[:, :, self.column_indices[name]] for name in self.label_columns],
        axis=-1)

  # Slicing doesn't preserve static shape information, so set the shapes
  # manually. This way the `tf.data.Datasets` are easier to inspect.
  inputs.set_shape([None, self.input_width, None])
  labels.set_shape([None, self.label_width, None])

  return inputs, labels

WindowGenerator.split_window = split_window

# plot function
def plot(self, model=None, plot_col='nuovi_positivi_Lombardia', max_subplots=32):
  inputs, labels = self.example
  plt.figure(figsize=(12, 8))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.figure()
    #plt.subplot(max_n, 1, n+1)
    plt.ylabel(f'{plot_col} [normed]')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [h]')

WindowGenerator.plot = plot

# make tf.dataset
def make_dataset(self, data, batch_size):
  data = np.array(data, dtype=np.float32)
  ds = tf.keras.utils.timeseries_dataset_from_array(
      data=data,
      targets=None,
      sequence_length=self.total_window_size,
      sequence_stride=1,
      shuffle=False,
      batch_size=batch_size,)

  ds = ds.map(self.split_window)

  return ds

WindowGenerator.make_dataset = make_dataset

# Properties
@property
def train(self):
  return self.make_dataset(self.train_df, self.batch_size)

@property
def val(self):
  return self.make_dataset(self.val_df, self.batch_size)

@property
def test(self):
  return self.make_dataset(self.test_df, self.batch_size)

@property
def example(self):
  """Get and cache an example batch of `inputs, labels` for plotting."""
  result = getattr(self, '_example', None)
  if result is None:
    # No example batch was found, so get one from the `.train` dataset
    result = next(iter(self.train))
    # And cache it for next time
    self._example = result
  return result

WindowGenerator.train = train
WindowGenerator.val = val
WindowGenerator.test = test
WindowGenerator.example = example

# %% [markdown]
# ## Training-Validation-Test sets creation

# %%
df_by_region['Sicilia'].plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='data'>, <AxesSubplot:xlabel='data'>,
#        <AxesSubplot:xlabel='data'>, <AxesSubplot:xlabel='data'>],
#       dtype=object)

# %%
regions_train = ["Sicilia"]   # name of regions to train simultaneously

NORMALIZATION = False
PCT_CHANGE = True
DIFF = False
APPLY_SMOOTHING = False
VALIDATION = False

all_df = dict()
all_df_1 = dict()
all_df_2 = dict()
train_df = dict() # dictionary of training dataFrames 
if VALIDATION:
    val_df = dict() # dictionary of validation dataframes
test_df = dict() # dictionary of test dataframes

OUT_STEPS = 7 # length of prediction horizon (OUTPUT OF NN)
IN_STEPS = 28 # length of input horizon (INPUT OF NN)
SHIFT = OUT_STEPS # Can be different from OUT_STEPS (to be used with care)

time_steps_for_test = OUT_STEPS # Numbers of days to keep out for the validation (in principle it should be of length: OUT_STEP+IN_STEPS), but we can use just OUT_STEPS
if VALIDATION:
    time_steps_for_validation = IN_STEPS+OUT_STEPS

# FOR THE NORMALIZATION I USE THE MEANS OF TRAIN FOR BOTH TRAINING AND TESTING
for reg in regions_train:

    mean = 0
    std = 1

    if PCT_CHANGE:

      all_df_1[reg] = copy.deepcopy(df_by_region[reg].loc[ ((df_by_region[reg].index >= cut_date_1) & (df_by_region[reg].index <= cut_date_2)) ])
      all_df_2[reg] = copy.deepcopy(df_by_region[reg].loc[ (df_by_region[reg].index >= cut_date_3)])
      all_df_1[reg] = all_df_1[reg].pct_change().dropna()
      all_df_2[reg] = all_df_2[reg].pct_change().dropna()
      all_df[reg] = pd.concat([all_df_1[reg], all_df_2[reg]], axis = 0, ignore_index = True)
    
    if DIFF:

      all_df_1[reg] = copy.deepcopy(df_by_region[reg].loc[ ((df_by_region[reg].index >= cut_date_1) & (df_by_region[reg].index <= cut_date_2)) ])
      all_df_2[reg] = copy.deepcopy(df_by_region[reg].loc[ (df_by_region[reg].index >= cut_date_3)])
      all_df_1[reg] = all_df_1[reg].diff().dropna()
      all_df_2[reg] = all_df_2[reg].diff().dropna()
      all_df[reg] = pd.concat([all_df_1[reg], all_df_2[reg]], axis = 0, ignore_index = True)
    
    if NORMALIZATION:
      mean = all_df[reg].iloc[:-time_steps_for_test,:].mean()
      std = all_df[reg].iloc[:-time_steps_for_test,:].std()
      
    all_df[reg] = ( all_df[reg] - mean ) / std

    if APPLY_SMOOTHING:
        
        window_length = 3 # MUST BE ODD; if you put 7 you obtain just the trend
        polyorder = 1 # Try also 2, 3, ...
        
        all_df[reg].loc[:, "{}_{}".format("nuovi_positivi", reg)] = savgol_filter(
                all_df[reg].loc[:, "{}_{}".format("nuovi_positivi", reg)],
                window_length,
                polyorder
            )
    
    if VALIDATION:
        train_df[reg] = all_df[reg].iloc[:-(time_steps_for_test + time_steps_for_validation),:]
        val_df[reg] = all_df[reg].iloc[ -(time_steps_for_test + time_steps_for_validation) : -time_steps_for_test, :]
        test_df[reg] = all_df[reg].iloc[-time_steps_for_test:,:]
    else:
        train_df[reg] = all_df[reg].iloc[:-time_steps_for_test,:]
        test_df[reg] = all_df[reg].iloc[-time_steps_for_test:,:]


    train_df[regions_train[0]] = train_df[regions_train[0]].replace([np.inf, -np.inf], np.nan).dropna()

windows = dict() # dictionary of windows for each region

batch_size = 4
    
for reg in regions_train:
    if VALIDATION:
        windows[reg] =  WindowGenerator(input_width=IN_STEPS,
                                        label_width=OUT_STEPS,
                                        shift=SHIFT,
                                        train_df = train_df[reg],
                                        val_df = val_df[reg],
                                        batch_size = batch_size, ### DEAFULT = 32; can be modified by hand being careful
                                        #label_columns=['{}_{}'.format("nuovi_positivi", reg)] ### labels to train; we might split the training for the features since it may help the models...
                                        )
    else:
        windows[reg] =  WindowGenerator(input_width=IN_STEPS,
                                label_width=OUT_STEPS,
                                shift=SHIFT,
                                train_df = train_df[reg],
                                batch_size = batch_size, ### DEAFULT = 32; can be modified by hand being careful
                                #label_columns=['{}_{}'.format("nuovi_positivi", reg)] ### labels to train; we might split the training for the features since it may help the models...
                                )
        
def plot_feature(reg, feature, model = None, max_figures = 3):
    windows[reg].plot(model = model, plot_col = "{}_{}".format(feature, region), max_subplots=max_figures)
    plt.xticks(rotation=90)
    print("To view all the figures, increase max_figures")

# %%
# Drop eventual +inf or Nan (necessary for Sicilia)

train_df[regions_train[0]] = train_df[regions_train[0]].replace([np.inf, -np.inf], np.nan).dropna()
train_df[regions_train[0]][train_df[regions_train[0]].isna().any(axis=1)]
train_df[regions_train[0]] = train_df[regions_train[0]].dropna()

# %%
# check the training
train_df[regions_train[0]].plot(subplots=True)
plt.xticks(rotation=90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Plot for viewing the batches
region = regions_train[0] # modify by hand for groups
feature = "nuovi_positivi" #nuovi_positivi, dimessi_guariti, #totale_ospedalizzati
plot_feature(region, feature, max_figures=20)
# Out:
# 2022-04-29 09:17:28.188263: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-04-29 09:17:28.188297: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-29 09:17:28.188312: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-H65JH0S): /proc/driver/nvidia/version does not exist
# 2022-04-29 09:17:28.188541: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# To view all the figures, increase max_figures

# %%
# Creation Training set for RNN

# Single region
if len(regions_train) == 1:

    X_train = windows[regions_train[0]].train
    
    try:
        X_val =  windows[regions_train[0]].val
    except:
        print("Cannot create X_val for trainf with the given window size or val_df not present")
        X_val = None

# Multiple regions
elif len(regions_train) > 1:
    
    print("More than one region...")
    
    for i in range(len(regions_train)-1):
        
        X_train = windows[regions_train[i]].train.concatenate(windows[regions_train[i+1]].train)
        
        try:
            X_val = windows[regions_train[i]].val.concatenate(windows[regions_train[i+1]].val)
        except:
            print("Cannot create X_val for trainf with the given window size or val_df not present")
            X_val = None
# Out:
# Cannot create X_val for trainf with the given window size or val_df not present

# %%
# IN THIS WAY YOU CAN EXTRACT THE TRAINING DATASET (Solution to the problem highlighted by Nove)
len(list(X_train.as_numpy_iterator()))
# Out:
# 103

# %% [markdown]
# ## Multi-Steps

# %%
def compile_and_fit(model, X_train, MAX_EPOCHS = 200, X_val = None, patience=30, custom_loss = None):
    
    if custom_loss == None:
    
        if X_val == None:
            monitor_loss = 'loss'
        else:
            monitor_loss = 'val_loss'
    else:
        monitor_loss = custom_loss
    
    
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor=monitor_loss, 
                                                    patience=patience,
                                                    mode='min')
  
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor=monitor_loss, 
                                                   factor=0.2,
                                                   patience=patience, 
                                                   min_lr=0.0001)
  
    #easy_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath = '/content/drive/Othercomputers/Laptop/homework3/Data/checkpoint_' + reg + '.h5',
    #                                                     save_weights_only = False, save_freq = 'epoch', monitor = monitor_loss, mode='min', 
    #                                                     save_best_only = True, verbose = 1)

    model.compile(loss=tf.losses.MeanSquaredError(),
                    optimizer=tf.optimizers.Adam(),
                    metrics=[tf.metrics.MeanAbsoluteError()])

    history = model.fit(X_train, epochs=MAX_EPOCHS,
                          validation_data=X_val,
                          callbacks=[early_stopping, reduce_lr])    #callbacks= [early_stopping, easy_checkpoint])

    return history

# %%
# # Run if we want to start from an old model
# multi_lstm_model = tf.keras.models.load_model('/content/drive/Othercomputers/Laptop/homework3/Data/checkpoint_' + reg + '.h5')

# %%
# Current best model for Sicilia

num_features = 4

multi_lstm_model = tf.keras.Sequential([
    # Shape [batch, time, features] => [batch, lstm_units].
    # Adding more `lstm_units` just overfits more quickly.
    tf.keras.layers.LSTM(32, return_sequences=False, kernel_regularizer=tf.keras.regularizers.L1L2(l1=1e-4, l2=1e-2)), #activation='selu'),
    # Shape => [batch, out_steps*features].
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros()),
    # Shape => [batch, out_steps, features].
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

# %%
multi_lstm_model.summary()    #right if gives error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 multi_lstm_model.summary()
#
# File ~/miniconda3/envs/SCT/lib/python3.8/site-packages/keras/engine/training.py:2775, in Model.summary(self, line_length, positions, print_fn, expand_nested, show_trainable)
#    2753 """Prints a string summary of the network.
#    2754
#    2755 Args:
#    (...)
#    2772     ValueError: if `summary()` is called before the model is built.
#    2773 """
#    2774 if not self.built:
# -> 2775   raise ValueError(
#    2776       'This model has not yet been built. '
#    2777       'Build the model first by calling `build()` or by calling '
#    2778       'the model on a batch of data.')
#    2779 layer_utils.print_summary(
#    2780     self,
#    2781     line_length=line_length,
#    (...)
#    2784     expand_nested=expand_nested,
#    2785     show_trainable=show_trainable)
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or by calling the model on a batch of data.

# %%
if VALIDATION:
    history = compile_and_fit(multi_lstm_model, X_train, X_val = X_val, MAX_EPOCHS = 300, patience = 15)
else:
    history = compile_and_fit(multi_lstm_model, X_train, MAX_EPOCHS = 300, patience = 15)
# Out:
# Epoch 1/300
# 103/103 [==============================] - 2s 6ms/step - loss: 0.1099 - mean_absolute_error: 0.0804 - lr: 0.0010
# Epoch 2/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0772 - mean_absolute_error: 0.0824 - lr: 0.0010
# Epoch 3/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0696 - mean_absolute_error: 0.0813 - lr: 0.0010
# Epoch 4/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0688 - mean_absolute_error: 0.0817 - lr: 0.0010
# Epoch 5/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0687 - mean_absolute_error: 0.0817 - lr: 0.0010
# Epoch 6/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0686 - mean_absolute_error: 0.0817 - lr: 0.0010
# Epoch 7/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0686 - mean_absolute_error: 0.0817 - lr: 0.0010
# Epoch 8/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0686 - mean_absolute_error: 0.0817 - lr: 0.0010
# Epoch 9/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0686 - mean_absolute_error: 0.0817 - lr: 0.0010
# Epoch 10/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0686 - mean_absolute_error: 0.0817 - lr: 0.0010
# Epoch 11/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0686 - mean_absolute_error: 0.0817 - lr: 0.0010
# Epoch 12/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0685 - mean_absolute_error: 0.0816 - lr: 0.0010
# Epoch 13/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0685 - mean_absolute_error: 0.0816 - lr: 0.0010
# Epoch 14/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0684 - mean_absolute_error: 0.0816 - lr: 0.0010
# Epoch 15/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0683 - mean_absolute_error: 0.0816 - lr: 0.0010
# Epoch 16/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0682 - mean_absolute_error: 0.0815 - lr: 0.0010
# Epoch 17/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0679 - mean_absolute_error: 0.0813 - lr: 0.0010
# Epoch 18/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0667 - mean_absolute_error: 0.0815 - lr: 0.0010
# Epoch 19/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0664 - mean_absolute_error: 0.0820 - lr: 0.0010
# Epoch 20/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0646 - mean_absolute_error: 0.0822 - lr: 0.0010
# Epoch 21/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0656 - mean_absolute_error: 0.0831 - lr: 0.0010
# Epoch 22/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0642 - mean_absolute_error: 0.0827 - lr: 0.0010
# Epoch 23/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0642 - mean_absolute_error: 0.0831 - lr: 0.0010
# Epoch 24/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0638 - mean_absolute_error: 0.0829 - lr: 0.0010
# Epoch 25/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0637 - mean_absolute_error: 0.0832 - lr: 0.0010
# Epoch 26/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0636 - mean_absolute_error: 0.0831 - lr: 0.0010
# Epoch 27/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0634 - mean_absolute_error: 0.0832 - lr: 0.0010
# Epoch 28/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0635 - mean_absolute_error: 0.0832 - lr: 0.0010
# Epoch 29/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0631 - mean_absolute_error: 0.0830 - lr: 0.0010
# Epoch 30/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0629 - mean_absolute_error: 0.0835 - lr: 0.0010
# Epoch 31/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0631 - mean_absolute_error: 0.0835 - lr: 0.0010
# Epoch 32/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0628 - mean_absolute_error: 0.0831 - lr: 0.0010
# Epoch 33/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0623 - mean_absolute_error: 0.0835 - lr: 0.0010
# Epoch 34/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0624 - mean_absolute_error: 0.0837 - lr: 0.0010
# Epoch 35/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0619 - mean_absolute_error: 0.0833 - lr: 0.0010
# Epoch 36/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0617 - mean_absolute_error: 0.0837 - lr: 0.0010
# Epoch 37/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0616 - mean_absolute_error: 0.0839 - lr: 0.0010
# Epoch 38/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0609 - mean_absolute_error: 0.0840 - lr: 0.0010
# Epoch 39/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0605 - mean_absolute_error: 0.0834 - lr: 0.0010
# Epoch 40/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0590 - mean_absolute_error: 0.0836 - lr: 0.0010
# Epoch 41/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0579 - mean_absolute_error: 0.0829 - lr: 0.0010
# Epoch 42/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0579 - mean_absolute_error: 0.0826 - lr: 0.0010
# Epoch 43/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0570 - mean_absolute_error: 0.0813 - lr: 0.0010
# Epoch 44/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0563 - mean_absolute_error: 0.0814 - lr: 0.0010
# Epoch 45/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0595 - mean_absolute_error: 0.0811 - lr: 0.0010
# Epoch 46/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0564 - mean_absolute_error: 0.0816 - lr: 0.0010
# Epoch 47/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0591 - mean_absolute_error: 0.0820 - lr: 0.0010
# Epoch 48/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0545 - mean_absolute_error: 0.0825 - lr: 0.0010
# Epoch 49/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0571 - mean_absolute_error: 0.0809 - lr: 0.0010
# Epoch 50/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0611 - mean_absolute_error: 0.0837 - lr: 0.0010
# Epoch 51/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0648 - mean_absolute_error: 0.0823 - lr: 0.0010
# Epoch 52/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0540 - mean_absolute_error: 0.0800 - lr: 0.0010
# Epoch 53/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0527 - mean_absolute_error: 0.0802 - lr: 0.0010
# Epoch 54/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0519 - mean_absolute_error: 0.0795 - lr: 0.0010
# Epoch 55/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0510 - mean_absolute_error: 0.0798 - lr: 0.0010
# Epoch 56/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0525 - mean_absolute_error: 0.0795 - lr: 0.0010
# Epoch 57/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0518 - mean_absolute_error: 0.0786 - lr: 0.0010
# Epoch 58/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0662 - mean_absolute_error: 0.0819 - lr: 0.0010
# Epoch 59/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0603 - mean_absolute_error: 0.0787 - lr: 0.0010
# Epoch 60/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0522 - mean_absolute_error: 0.0805 - lr: 0.0010
# Epoch 61/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0498 - mean_absolute_error: 0.0792 - lr: 0.0010
# Epoch 62/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0561 - mean_absolute_error: 0.0804 - lr: 0.0010
# Epoch 63/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0661 - mean_absolute_error: 0.0814 - lr: 0.0010
# Epoch 64/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0535 - mean_absolute_error: 0.0774 - lr: 0.0010
# Epoch 65/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0498 - mean_absolute_error: 0.0799 - lr: 0.0010
# Epoch 66/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0579 - mean_absolute_error: 0.0797 - lr: 0.0010
# Epoch 67/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0606 - mean_absolute_error: 0.0782 - lr: 0.0010
# Epoch 68/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0504 - mean_absolute_error: 0.0802 - lr: 0.0010
# Epoch 69/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0568 - mean_absolute_error: 0.0805 - lr: 0.0010
# Epoch 70/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0539 - mean_absolute_error: 0.0779 - lr: 0.0010
# Epoch 71/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0485 - mean_absolute_error: 0.0787 - lr: 0.0010
# Epoch 72/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0523 - mean_absolute_error: 0.0780 - lr: 0.0010
# Epoch 73/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0675 - mean_absolute_error: 0.0802 - lr: 0.0010
# Epoch 74/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0575 - mean_absolute_error: 0.0774 - lr: 0.0010
# Epoch 75/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0485 - mean_absolute_error: 0.0800 - lr: 0.0010
# Epoch 76/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0464 - mean_absolute_error: 0.0775 - lr: 0.0010
# Epoch 77/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0476 - mean_absolute_error: 0.0769 - lr: 0.0010
# Epoch 78/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0462 - mean_absolute_error: 0.0765 - lr: 0.0010
# Epoch 79/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0453 - mean_absolute_error: 0.0755 - lr: 0.0010
# Epoch 80/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0440 - mean_absolute_error: 0.0739 - lr: 0.0010
# Epoch 81/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0468 - mean_absolute_error: 0.0755 - lr: 0.0010
# Epoch 82/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0612 - mean_absolute_error: 0.0801 - lr: 0.0010
# Epoch 83/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0538 - mean_absolute_error: 0.0766 - lr: 0.0010
# Epoch 84/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0496 - mean_absolute_error: 0.0805 - lr: 0.0010
# Epoch 85/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0435 - mean_absolute_error: 0.0758 - lr: 0.0010
# Epoch 86/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0432 - mean_absolute_error: 0.0746 - lr: 0.0010
# Epoch 87/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0430 - mean_absolute_error: 0.0740 - lr: 0.0010
# Epoch 88/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0421 - mean_absolute_error: 0.0721 - lr: 0.0010
# Epoch 89/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0418 - mean_absolute_error: 0.0718 - lr: 0.0010
# Epoch 90/300
# 103/103 [==============================] - 1s 7ms/step - loss: 0.0434 - mean_absolute_error: 0.0737 - lr: 0.0010
# Epoch 91/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0406 - mean_absolute_error: 0.0724 - lr: 0.0010
# Epoch 92/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0427 - mean_absolute_error: 0.0753 - lr: 0.0010
# Epoch 93/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0452 - mean_absolute_error: 0.0776 - lr: 0.0010
# Epoch 94/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0419 - mean_absolute_error: 0.0760 - lr: 0.0010
# Epoch 95/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0430 - mean_absolute_error: 0.0763 - lr: 0.0010
# Epoch 96/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0417 - mean_absolute_error: 0.0736 - lr: 0.0010
# Epoch 97/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0635 - mean_absolute_error: 0.0787 - lr: 0.0010
# Epoch 98/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0459 - mean_absolute_error: 0.0716 - lr: 0.0010
# Epoch 99/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0605 - mean_absolute_error: 0.0762 - lr: 0.0010
# Epoch 100/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0430 - mean_absolute_error: 0.0719 - lr: 0.0010
# Epoch 101/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0420 - mean_absolute_error: 0.0724 - lr: 0.0010
# Epoch 102/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0408 - mean_absolute_error: 0.0705 - lr: 0.0010
# Epoch 103/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0392 - mean_absolute_error: 0.0706 - lr: 0.0010
# Epoch 104/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0393 - mean_absolute_error: 0.0702 - lr: 0.0010
# Epoch 105/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0394 - mean_absolute_error: 0.0709 - lr: 0.0010
# Epoch 106/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0399 - mean_absolute_error: 0.0703 - lr: 0.0010
# Epoch 107/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0398 - mean_absolute_error: 0.0720 - lr: 0.0010
# Epoch 108/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0390 - mean_absolute_error: 0.0707 - lr: 0.0010
# Epoch 109/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0384 - mean_absolute_error: 0.0696 - lr: 0.0010
# Epoch 110/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0412 - mean_absolute_error: 0.0726 - lr: 0.0010
# Epoch 111/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0387 - mean_absolute_error: 0.0711 - lr: 0.0010
# Epoch 112/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0644 - mean_absolute_error: 0.0795 - lr: 0.0010
# Epoch 113/300
# 103/103 [==============================] - 1s 7ms/step - loss: 0.0450 - mean_absolute_error: 0.0724 - lr: 0.0010
# Epoch 114/300
# 103/103 [==============================] - 1s 7ms/step - loss: 0.0394 - mean_absolute_error: 0.0711 - lr: 0.0010
# Epoch 115/300
# 103/103 [==============================] - 1s 7ms/step - loss: 0.0390 - mean_absolute_error: 0.0706 - lr: 0.0010
# Epoch 116/300
# 103/103 [==============================] - 1s 7ms/step - loss: 0.0387 - mean_absolute_error: 0.0689 - lr: 0.0010
# Epoch 117/300
# 103/103 [==============================] - 1s 7ms/step - loss: 0.0392 - mean_absolute_error: 0.0707 - lr: 0.0010
# Epoch 118/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0378 - mean_absolute_error: 0.0685 - lr: 0.0010
# Epoch 119/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0405 - mean_absolute_error: 0.0720 - lr: 0.0010
# Epoch 120/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0400 - mean_absolute_error: 0.0715 - lr: 0.0010
# Epoch 121/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0417 - mean_absolute_error: 0.0726 - lr: 0.0010
# Epoch 122/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0585 - mean_absolute_error: 0.0782 - lr: 0.0010
# Epoch 123/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0423 - mean_absolute_error: 0.0711 - lr: 0.0010
# Epoch 124/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0591 - mean_absolute_error: 0.0756 - lr: 0.0010
# Epoch 125/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0412 - mean_absolute_error: 0.0722 - lr: 0.0010
# Epoch 126/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0394 - mean_absolute_error: 0.0725 - lr: 0.0010
# Epoch 127/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0375 - mean_absolute_error: 0.0693 - lr: 0.0010
# Epoch 128/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0375 - mean_absolute_error: 0.0693 - lr: 0.0010
# Epoch 129/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0394 - mean_absolute_error: 0.0697 - lr: 0.0010
# Epoch 130/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0374 - mean_absolute_error: 0.0689 - lr: 0.0010
# Epoch 131/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0375 - mean_absolute_error: 0.0689 - lr: 0.0010
# Epoch 132/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0374 - mean_absolute_error: 0.0684 - lr: 0.0010
# Epoch 133/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0380 - mean_absolute_error: 0.0687 - lr: 0.0010
# Epoch 134/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0377 - mean_absolute_error: 0.0688 - lr: 0.0010
# Epoch 135/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0370 - mean_absolute_error: 0.0689 - lr: 0.0010
# Epoch 136/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0383 - mean_absolute_error: 0.0709 - lr: 0.0010
# Epoch 137/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0372 - mean_absolute_error: 0.0697 - lr: 0.0010
# Epoch 138/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0374 - mean_absolute_error: 0.0690 - lr: 0.0010
# Epoch 139/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0374 - mean_absolute_error: 0.0695 - lr: 0.0010
# Epoch 140/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0392 - mean_absolute_error: 0.0696 - lr: 0.0010
# Epoch 141/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0415 - mean_absolute_error: 0.0729 - lr: 0.0010
# Epoch 142/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0399 - mean_absolute_error: 0.0708 - lr: 0.0010
# Epoch 143/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0395 - mean_absolute_error: 0.0708 - lr: 0.0010
# Epoch 144/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0388 - mean_absolute_error: 0.0704 - lr: 0.0010
# Epoch 145/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0388 - mean_absolute_error: 0.0703 - lr: 0.0010
# Epoch 146/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0386 - mean_absolute_error: 0.0706 - lr: 0.0010
# Epoch 147/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0399 - mean_absolute_error: 0.0698 - lr: 0.0010
# Epoch 148/300
# 103/103 [==============================] - 1s 5ms/step - loss: 0.0373 - mean_absolute_error: 0.0701 - lr: 0.0010
# Epoch 149/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0389 - mean_absolute_error: 0.0694 - lr: 0.0010
# Epoch 150/300
# 103/103 [==============================] - 1s 6ms/step - loss: 0.0375 - mean_absolute_error: 0.0697 - lr: 0.0010

# %%
region = regions_train[0]
feature = "nuovi_positivi"  #nuovi_positivi, dimessi_guariti, #totale_ospedalizzati #deceduti
plot_feature(region, feature, multi_lstm_model, 10)

# THE MODEL DOES NOT LEARN NUOVI_POSITVI: I THINK IT'S BEACUSE THE OTHER FEATURES HAVE AN INCREASING AND A DECREASING TREND,
# AND THE NN IS CONFUSED. FIRST LET'S SEE IF PCT_CHANGE OR DIFF CHANGE SOMETHING ...
# Out:
# To view all the figures, increase max_figures

# %%
region = regions_train[0]

if VALIDATION:
    pred_x_predict = multi_lstm_model(np.array(val_df[reg].iloc[-IN_STEPS:,:]).reshape(1, IN_STEPS, 4)) 
    pred_x_predict
else:
    pred_x_predict = multi_lstm_model(np.array(train_df[reg].iloc[-IN_STEPS:,:]).reshape(1, IN_STEPS, 4))
    pred_x_predict

# %%
pr = tf.squeeze(pred_x_predict)
prd = pd.DataFrame(pr.numpy())

idx = test_df[reg].index

predictions = prd.rename(columns={0: 'pred_totale_ospedalizzati_' + reg, 
                                  1: 'pred_nuovi_positivi_' + reg,
                                  2: 'pred_dimessi_guariti_' + reg,
                                  3: 'pred_deceduti_' + reg},
                          index={ 0: idx[0],
                                  1: idx[1],
                                  2: idx[2],
                                  3: idx[3],
                                  4: idx[4],
                                  5: idx[5],
                                  6: idx[6]})

# %%
predictions
# Out:
#      pred_totale_ospedalizzati_Sicilia  pred_nuovi_positivi_Sicilia  \
# 444                          -0.002076                     0.012600
# 445                          -0.035098                     0.131609
# 446                          -0.025857                    -0.138225
# 447                          -0.009229                    -0.527656
# 448                           0.027389                    -0.246012
# 449                          -0.032196                     3.111672
# 450                          -0.024565                    -0.211551
#
#      pred_dimessi_guariti_Sicilia  pred_deceduti_Sicilia
# 444                      0.015059              -0.009956
# 445                      0.014467              -0.012782
# 446                      0.002497              -0.002784
# 447                     -0.000261              -0.002728
# 448                      0.003415              -0.006055
# 449                      0.003120              -0.004392
# 450                      0.006027              -0.010199

# %%
test_df[reg]
# Out:
#      totale_ospedalizzati_Sicilia  nuovi_positivi_Sicilia  \
# 444                     -0.046187               -0.000591
# 445                     -0.013514               -0.026005
# 446                     -0.011416               -0.188107
# 447                     -0.005774               -0.557299
# 448                      0.037166                0.014631
# 449                      0.020157                2.632834
# 450                     -0.015368               -0.373130
#
#      dimessi_guariti_Sicilia  deceduti_Sicilia
# 444                 0.009783          0.002587
# 445                 0.008661          0.001338
# 446                 0.001381          0.000668
# 447                 0.001603          0.000668
# 448                 0.001495          0.001048
# 449                 0.004900          0.002380
# 450                 0.004705          0.001900

# %%
concatenated_df = pd.concat([predictions, test_df[reg]], axis=1)

errors = pd.DataFrame()
for i in range(4):
  errors = pd.concat([errors, concatenated_df.iloc[:, i] - concatenated_df.iloc[:, i+4]], axis = 1, ignore_index=True)

# %%
errors    #ordine: totale_ospedalizzati	nuovi_positivi	dimessi_guariti	deceduti
# Out:
#             0         1         2         3
# 444  0.044111  0.013190  0.005276 -0.012543
# 445 -0.021584  0.157614  0.005805 -0.014120
# 446 -0.014441  0.049882  0.001116 -0.003452
# 447 -0.003456  0.029643 -0.001864 -0.003396
# 448 -0.009778 -0.260643  0.001921 -0.007103
# 449 -0.052353  0.478838 -0.001780 -0.006772
# 450 -0.009198  0.161579  0.001322 -0.012098

# %%
# Nuovi positivi 

plt.scatter(predictions.index, predictions['pred_nuovi_positivi_Sicilia'], label = 'Predictions')
plt.scatter(predictions.index, test_df[reg]['nuovi_positivi_Sicilia'], label = 'Data')
plt.legend()

# %%
# Totale ospedalizzati

plt.scatter(predictions.index, predictions['pred_totale_ospedalizzati_Sicilia'], label = 'Predictions')
plt.scatter(predictions.index, test_df[reg]['totale_ospedalizzati_Sicilia'], label = 'Data')
plt.legend()

# %%
# Dimessi guariti

plt.scatter(predictions.index, predictions['pred_dimessi_guariti_Sicilia'], label = 'Predictions')
plt.scatter(predictions.index, test_df[reg]['dimessi_guariti_Sicilia'], label = 'Data')
plt.legend()

# %%
# Deceduti 

plt.scatter(predictions.index, predictions['pred_deceduti_Sicilia'], label = 'Predictions')
plt.scatter(predictions.index, test_df[reg]['deceduti_Sicilia'], label = 'Data')
plt.legend()

# %%
prova = np.ones((IN_STEPS,4)).reshape(1,IN_STEPS,4)
multi_lstm_model.predict(prova)
# Out:
# array([[[ 0.00350263, -0.19991964,  0.01011838,  0.00496612],
#         [ 0.00535695,  0.16375262,  0.00832496,  0.00164275],
#         [ 0.01005139,  0.01292119,  0.00753853,  0.00386039],
#         [ 0.0058418 ,  0.16313446,  0.01027333,  0.00432421],
#         [ 0.00918086,  0.06537901,  0.01097053,  0.00354033],
#         [ 0.00481946,  0.14256395,  0.0085947 ,  0.0042535 ],
#         [ 0.00063444,  0.20082128,  0.00975225,  0.00354939]]],
#       dtype=float32)

# %% [markdown]
# ### Back to original scale

# %%
init = df_by_region[reg].iloc[-time_steps_for_test-1,:]
init = pd.DataFrame(init).T

initial = init.rename(columns={'totale_ospedalizzati_' + reg: 'pred_totale_ospedalizzati_' + reg, 
                               'nuovi_positivi_' + reg: 'pred_nuovi_positivi_' + reg,
                               'dimessi_guariti_' + reg: 'pred_dimessi_guariti_' + reg,
                               'deceduti_' + reg: 'pred_deceduti_' + reg} )

pred_original_scale = (1 + predictions).cumprod() * initial.iloc[0,:]

# %%
# Error with original data

idx_true = df_by_region[reg].iloc[-time_steps_for_test:,:].index
idx_pred = pred_original_scale.index
true_test = df_by_region[reg].iloc[-time_steps_for_test:,:].rename(index={idx_true[0]: idx_pred[0], 
                                                                          idx_true[1]: idx_pred[1], 
                                                                          idx_true[2]: idx_pred[2], 
                                                                          idx_true[3]: idx_pred[3], 
                                                                          idx_true[4]: idx_pred[4], 
                                                                          idx_true[5]: idx_pred[5], 
                                                                          idx_true[6]: idx_pred[6]} )

original_concatenated_df = pd.concat([pred_original_scale, true_test], axis=1 )

original_errors = pd.DataFrame()
for i in range(4):
  original_errors = pd.concat([original_errors, original_concatenated_df.iloc[:, i] - original_concatenated_df.iloc[:, i+4]], axis = 1, ignore_index=True)

original_err = original_errors.rename(columns={0: 'totale_ospedalizzati_' + reg, 
                                               1: 'nuovi_positivi_' + reg,
                                               2: 'dimessi_guariti_' + reg,
                                               3: 'deceduti_' + reg} )

original_error = (original_err * std) + mean

original_error_perc = (original_error / true_test) * 100

# %%
original_error_perc # percentage error on true values
# Out:
#      totale_ospedalizzati_Sicilia  nuovi_positivi_Sicilia  \
# 444                      4.624743                1.319817
# 445                      2.335546               17.715547
# 446                      0.840630               24.947870
# 447                      0.490132               33.314438
# 448                     -0.457200               -0.932031
# 449                     -5.565591               12.125967
# 450                     -6.447711               41.027012
#
#      dimessi_guariti_Sicilia  deceduti_Sicilia
# 444                 0.522451         -1.251058
# 445                 1.100986         -2.643526
# 446                 1.213688         -2.979349
# 447                 1.025347         -3.308599
# 448                 1.219081         -3.994694
# 449                 1.039762         -4.643325
# 450                 1.172764         -5.794799

# %% [markdown]
# ## CSV creation for Webeep

# %%
new_predictions =  multi_lstm_model(np.array(all_df[reg].iloc[-IN_STEPS:,:]).reshape(1, IN_STEPS, 4))

# %%
new_predictions_df = pd.DataFrame(new_predictions.numpy().reshape(7,4))
new_predictions_df = new_predictions_df.rename(columns={0: 'pred_totale_ospedalizzati_' + reg, 
                                                  1: 'pred_nuovi_positivi_' + reg,
                                                  2: 'pred_dimessi_guariti_' + reg,
                                                  3: 'pred_deceduti_' + reg})

# %%
new_predictions_df_orig_scale = (1 + predictions).cumprod() * initial.iloc[0,:]

# %%
new_predictions_df_orig_scale.columns = ['hospitalized', 'newinfections', 'recovered', 'deceased']
new_predictions_df_orig_scale = new_predictions_df_orig_scale[['newinfections', 'hospitalized' , 'recovered' , 'deceased']]

# %%
new_predictions_df_orig_scale.to_csv('webeepUpload_' + reg +  '.csv', index=False)
